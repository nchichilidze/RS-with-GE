# %% [markdown]
# # Imports

# %%
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
movies = pd.read_csv('https://raw.githubusercontent.com/nchichilidze/RS-with-GE/main/preprocessed_movielens_1m/movies.csv')
tags = pd.read_csv('https://raw.githubusercontent.com/nchichilidze/RS-with-GE/main/preprocessed_movielens_1m/tags.csv')
ratings = pd.read_csv('https://raw.githubusercontent.com/nchichilidze/RS-with-GE/main/preprocessed_movielens_1m/ratings.csv')

movies = movies.iloc[: , 1:]
tags = tags.iloc[: , 1:]

# %%
movies.head()
tags.head()
# Out:
#    movie_id                                               tags  \
# 0         1  pixar pixar pixar animation pixar animated fun...
# 1         2  for children game animals joe johnston robin w...
# 2         3  funniest movies comedinha de velhinhos engraã ...
# 3         4  girl movie comedy drama comedy drama comedy dr...
# 4         5  steve martin pregnancy remake steve martin fam...
#
#                          title                        genres  year
# 0                    Toy Story   animation children's comedy  1995
# 1                      Jumanji  adventure children's fantasy  1995
# 2             Grumpier Old Men                comedy romance  1995
# 3            Waiting to Exhale                  comedy drama  1995
# 4  Father of the Bride Part II                        comedy  1995

# %%
movies.shape
# Out:
# (3883, 4)

# %%
imdb_ratings = pd.read_csv("title.ratings.tsv", sep='\t')
imdb_titles = pd.read_csv("title.basics.tsv", sep='\t')
# Out:
# /Users/nutsa/.pyenv/versions/3.7.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
imdb_ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001        5.70000      1864
# 1  tt0000002        6.00000       244
# 2  tt0000003        6.50000      1632
# 3  tt0000004        5.80000       158
# 4  tt0000005        6.20000      2458

# %%
imdb_titles['titleType'].unique()
# Out:
# array(['short', 'movie', 'tvEpisode', 'tvSeries', 'tvShort', 'tvMovie',
#        'tvMiniSeries', 'tvSpecial', 'video', 'videoGame', 'tvPilot'],
#       dtype=object)

# %%
# drop non movie titleTypes 

non_movie_titleTypes = ['tvEpisode', 'tvSeries', 'tvMiniSeries', 'video', 'videoGame', 'tvPilot']

for titleType in non_movie_titleTypes: 
    imdb_titles = imdb_titles[imdb_titles['titleType'] != titleType]

# %%
movies_full = movies.copy(deep=True)

# %%
movies_full['title'] = movies_full['title'].apply(lambda x: x.lower())

# %%
imdb_full = imdb_ratings.copy(deep=True)
imdb_full = pd.merge(imdb_full, imdb_titles, on='tconst')

# %%
imdb_full = imdb_full.rename(columns={'primaryTitle': 'title'})
imdb_full = imdb_full.rename(columns={'startYear': 'year'})
imdb_full = imdb_full.rename(columns={'genres': 'imdb_genres'})
imdb_full = imdb_full.drop(columns='endYear')
imdb_full['title'] = imdb_full['title'].apply(lambda x: x.lower())
imdb_full
# Out:
#            tconst  averageRating  numVotes titleType                   title  \
# 0       tt0000001        5.70000      1864     short              carmencita
# 1       tt0000002        6.00000       244     short  le clown et ses chiens
# 2       tt0000003        6.50000      1632     short          pauvre pierrot
# 3       tt0000004        5.80000       158     short             un bon bock
# 4       tt0000005        6.20000      2458     short        blacksmith scene
# ...           ...            ...       ...       ...                     ...
# 476672  tt9916460        9.30000        17   tvMovie               pink taxi
# 476673  tt9916538        8.30000         6     movie     kuambil lagi hatiku
# 476674  tt9916544        7.00000        51     short         my sweet prince
# 476675  tt9916720        5.70000       194     short               the nun 2
# 476676  tt9916730        8.40000         5     movie                  6 gunn
#
#                  originalTitle isAdult  year runtimeMinutes  \
# 0                   Carmencita       0  1894              1
# 1       Le clown et ses chiens       0  1892              5
# 2               Pauvre Pierrot       0  1892              4
# 3                  Un bon bock       0  1892             12
# 4             Blacksmith Scene       0  1893              1
# ...                        ...     ...   ...            ...
# 476672               Pink Taxi       0  2019             \N
# 476673     Kuambil Lagi Hatiku       0  2019            123
# 476674         My Sweet Prince       0  2019             12
# 476675               The Nun 2       0  2019             10
# 476676                  6 Gunn       0  2017            116
#
#                      imdb_genres
# 0              Documentary,Short
# 1                Animation,Short
# 2       Animation,Comedy,Romance
# 3                Animation,Short
# 4                   Comedy,Short
# ...                          ...
# 476672                    Comedy
# 476673                     Drama
# 476674               Drama,Short
# 476675     Comedy,Horror,Mystery
# 476676                        \N
#
# [476677 rows x 10 columns]

# %% [markdown]
# # discovering & fixing mismatches

# %%
# another mismatch is that MovieLens names movies in the format: Contender, The 
# IMDB names them in the format: The Contender

def reformat_title(title): 
    new_title = title;
    if(len(title) >= 5): 
        if (title[-5:] == ', the'):
            new_title = 'the '
            new_title += title[:-5]
    return new_title

movies_full['title'] = movies_full['title'].map(lambda x: reformat_title(x))

# %%
movies_and_imdb = pd.merge(movies_full, imdb_full, on=['title', 'year'])
movies_and_imdb.shape
# Out:
# (3086, 12)

# %% [markdown]
# matched 3086 out of 3883

# %%
unmatched = pd.merge(movies_full, imdb_full, on=['title', 'year'], how='left')
unmatched = unmatched.fillna(0)
unmatched = unmatched[unmatched['tconst'] == 0]
unmatched.head()
# Out:
#     movie_id                                          title  \
# 27        28                                     persuasion
# 29        30  shanghai triad (yao a yao yao dao waipo qiao)
# 31        32                                 twelve monkeys
# 46        47                                  seven (se7en)
# 51        51                                 guardian angel
#
#                    genres  year tconst  averageRating  numVotes titleType  \
# 27                romance  1995      0        0.00000   0.00000         0
# 29                  drama  1995      0        0.00000   0.00000         0
# 31           drama sci-fi  1995      0        0.00000   0.00000         0
# 46         crime thriller  1995      0        0.00000   0.00000         0
# 51  action drama thriller  1994      0        0.00000   0.00000         0
#
#    originalTitle isAdult runtimeMinutes imdb_genres
# 27             0       0              0           0
# 29             0       0              0           0
# 31             0       0              0           0
# 46             0       0              0           0
# 51             0       0              0           0

# %% [markdown]
# now I need to manually understand what other title mismatches there are

# %%
movies_full[movies_full['title'] == 'the slumber party massacre ii']
# Out:
#       movie_id                          title  genres  year
# 3869      3939  the slumber party massacre ii  horror  1987

# %%
# no match for the slumber party massacre ii and iii, try to change roman numberals into arabic, but it doesn't work
imdb_full[imdb_full['title'] == 'the slumber party massacre 2']
# Out:
# Empty DataFrame
# Columns: [tconst, averageRating, numVotes, titleType, title, originalTitle, isAdult, year, runtimeMinutes, imdb_genres]
# Index: []

# %%
# removed 'the' from the title and found a match in IMDB
imdb_full[imdb_full['title'] == 'slumber party massacre ii']
# Out:
#           tconst  averageRating  numVotes titleType  \
# 63061  tt0093996        4.60000      5816     movie
#
#                            title              originalTitle isAdult  year  \
# 63061  slumber party massacre ii  Slumber Party Massacre II       0  1987
#
#       runtimeMinutes          imdb_genres
# 63061             77  Comedy,Horror,Music

# %%
imdb_to_match = imdb_full.copy(deep=True)
imdb_to_match = imdb_to_match.drop(columns=['averageRating', 'numVotes', 'titleType', 'originalTitle', 'isAdult', 'runtimeMinutes', 'imdb_genres'])
imdb_to_match = imdb_to_match.rename(columns={'title' : 'imdb_title'})
imdb_to_match = imdb_to_match.rename(columns={'year' : 'imdb_year'})
imdb_to_match.head()
# Out:
#       tconst              imdb_title  imdb_year
# 0  tt0000001              carmencita       1894
# 1  tt0000002  le clown et ses chiens       1892
# 2  tt0000003          pauvre pierrot       1892
# 3  tt0000004             un bon bock       1892
# 4  tt0000005        blacksmith scene       1893

# %%
import string 
from string import digits 
from string import punctuation



unmatched_experiments = unmatched.copy(deep='True')
unmatched_experiments['with_article'] = ''
unmatched_experiments['without_article'] = ''
unmatched_experiments['no_punctuation'] = ''
unmatched_experiments['no_numbers'] = ''

for index, row in unmatched_experiments.iterrows(): 
    # for those who have 'the' at the beginning of the title, remove it 
    title = row['title']
    if title[:3] == 'the': 
        unmatched_experiments.at[index, 'without_article'] = title[4:]
    # for those who don't have 'the' at the beginning, add it on 
    else: 
        unmatched_experiments.at[index, 'with_article'] = 'the ' + title 

    if (any(p in title for p in punctuation)):
        title_no_punctuation = title.translate(str.maketrans('', '', string.punctuation))
        unmatched_experiments.at[index, 'no_punctuation'] = title_no_punctuation

        
    if (any(p.isdigit() for p in title)):
        title_no_numbers = title.translate(digits)
        unmatched_experiments.at[index, 'no_numbers'] = title_no_punctuation
    

unmatched_experiments = unmatched_experiments.astype({'with_article': 'string',
                                                      'without_article': 'string',
                                                      'no_punctuation': 'string',
                                                      'no_numbers': 'string',})

unmatched_experiments = unmatched_experiments.drop(columns=['genres', 'tconst', 'averageRating', 'numVotes', 'titleType', 'originalTitle', 'isAdult', 'runtimeMinutes', 'imdb_genres'])

# %%
imdb_to_match = imdb_to_match.astype({'tconst': 'string'})
imdb_to_match.dtypes
# Out:
# tconst        string
# imdb_title    string
# imdb_year      int64
# dtype: object

# %%
match_with_article = pd.merge(unmatched_experiments, imdb_to_match, 
                              left_on=['with_article', 'year'],
                              right_on=['imdb_title', 'imdb_year'],
                              how='left')

match_with_article = match_with_article[match_with_article['tconst'] != '<NA>']
print("Found matches for ")
print(len(match_with_article))
print("movies")
match_with_article
# Out:
# Found matches for
# 7
# movies
#      movie_id                       title  year  \
# 294      1340       bride of frankenstein  1935
# 310      1430                  underworld  1997
# 361      1771                 night flier  1997
# 557      2782        pit and the pendulum  1961
# 590      2919  year of living dangerously  1982
# 639      3130     bonfire of the vanities  1990
# 811      3856                autumn heart  1999
#
#                        with_article without_article no_punctuation no_numbers  \
# 294       the bride of frankenstein
# 310                  the underworld
# 361                 the night flier
# 557        the pit and the pendulum
# 590  the year of living dangerously
# 639     the bonfire of the vanities
# 811                the autumn heart
#
#         tconst                      imdb_title  imdb_year
# 294  tt0026138       the bride of frankenstein 1935.00000
# 310  tt0301971                  the underworld 1997.00000
# 361  tt0119784                 the night flier 1997.00000
# 557  tt0055304        the pit and the pendulum 1961.00000
# 590  tt0086617  the year of living dangerously 1982.00000
# 639  tt0099165     the bonfire of the vanities 1990.00000
# 811  tt0120593                the autumn heart 1999.00000

# %%
match_without_article = pd.merge(unmatched_experiments, imdb_to_match, 
                              left_on=['without_article', 'year'],
                              right_on=['imdb_title', 'imdb_year'],
                              how='left')

match_without_article = match_without_article[match_without_article['tconst'] != '<NA>']
print("Found matches for ")
print(len(match_without_article))
print("movies")
match_without_article
# Out:
# Found matches for
# 9
# movies
#      movie_id                               title  year with_article  \
# 426      2155          the slums of beverly hills  1998
# 612      2995           the house on haunted hill  1999
# 642      3140                      the three ages  1923
# 643      3145                the cradle will rock  1999
# 770      3670               the story of g.i. joe  1945
# 828      3930  the creature from the black lagoon  1954
# 830      3936            the phantom of the opera  1943
# 831      3939       the slumber party massacre ii  1987
# 832      3940      the slumber party massacre iii  1990
#
#                     without_article       no_punctuation no_numbers  \
# 426          slums of beverly hills
# 612           house on haunted hill
# 642                      three ages
# 643                cradle will rock
# 770               story of g.i. joe  the story of gi joe
# 828  creature from the black lagoon
# 830            phantom of the opera
# 831       slumber party massacre ii
# 832      slumber party massacre iii
#
#         tconst                      imdb_title  imdb_year
# 426  tt0120831          slums of beverly hills 1998.00000
# 612  tt0185371           house on haunted hill 1999.00000
# 642  tt0014538                      three ages 1923.00000
# 643  tt0150216                cradle will rock 1999.00000
# 770  tt0038120               story of g.i. joe 1945.00000
# 828  tt0046876  creature from the black lagoon 1954.00000
# 830  tt0036261            phantom of the opera 1943.00000
# 831  tt0093996       slumber party massacre ii 1987.00000
# 832  tt0100639      slumber party massacre iii 1990.00000

# %%
match_without_punctuation = pd.merge(unmatched_experiments, imdb_to_match, 
                              left_on=['no_punctuation', 'year'],
                              right_on=['imdb_title', 'imdb_year'],
                              how='left')

match_without_punctuation = match_without_punctuation[match_without_punctuation['tconst'] != '<NA>']
print("Found matches for ")
print(len(match_without_punctuation))
print("movies")
match_without_punctuation
# Out:
# Found matches for
# 23
# movies
#      movie_id                                              title  year  \
# 14        119                            steal big, steal little  1995
# 23        165                         die hard: with a vengeance  1995
# 80        468  the englishman who went up a hill, but came do...  1995
# 107       603                                      bye bye, love  1995
# 215      1066                                    shall we dance?  1937
# 278      1294                                            m*a*s*h  1970
# 316      1460                                     that darn cat!  1997
# 343      1684                                      mrs. dalloway  1997
# 374      1825                                  the player's club  1998
# 431      2171                              next stop, wonderland  1998
# 435      2190                         why do fools fall in love?  1998
# 448      2248                                    say anything...  1989
# 450      2262                                about last night...  1986
# 478      2421                            the karate kid, part ii  1986
# 527      2670                               run silent, run deep  1958
# 566      2811                         with friends like these...  1998
# 609      2981                     brother, can you spare a dime?  1975
# 610      2987                           who framed roger rabbit?  1988
# 705      3420                             ...and justice for all  1979
# 724      3516                              bell, book and candle  1958
# 773      3694                         the toxic avenger, part ii  1989
# 817      3878                                     x: the unknown  1956
# 819      3886                                  steal this movie!  2000
#
#                            with_article  \
# 14          the steal big, steal little
# 23       the die hard: with a vengeance
# 80
# 107                   the bye bye, love
# 215                 the shall we dance?
# 278                         the m*a*s*h
# 316                  the that darn cat!
# 343                   the mrs. dalloway
# 374
# 431           the next stop, wonderland
# 435      the why do fools fall in love?
# 448                 the say anything...
# 450             the about last night...
# 478
# 527            the run silent, run deep
# 566      the with friends like these...
# 609  the brother, can you spare a dime?
# 610        the who framed roger rabbit?
# 705          the ...and justice for all
# 724           the bell, book and candle
# 773
# 817                  the x: the unknown
# 819               the steal this movie!
#
#                                        without_article  \
# 14
# 23
# 80   englishman who went up a hill, but came down a...
# 107
# 215
# 278
# 316
# 343
# 374                                      player's club
# 431
# 435
# 448
# 450
# 478                                karate kid, part ii
# 527
# 566
# 609
# 610
# 705
# 724
# 773                             toxic avenger, part ii
# 817
# 819
#
#                                         no_punctuation no_numbers     tconst  \
# 14                              steal big steal little             tt0114536
# 23                           die hard with a vengeance             tt0112864
# 80   the englishman who went up a hill but came dow...             tt0112966
# 107                                       bye bye love             tt0112606
# 215                                     shall we dance             tt0029546
# 278                                               mash             tt0066026
# 316                                      that darn cat             tt0120317
# 343                                       mrs dalloway             tt0119723
# 374                                   the players club             tt0119905
# 431                               next stop wonderland             tt0119778
# 435                          why do fools fall in love             tt0123324
# 448                                       say anything             tt0098258
# 450                                   about last night             tt0090583
# 478                             the karate kid part ii             tt0091326
# 527                                run silent run deep             tt0052151
# 566                            with friends like these             tt0119692
# 609                       brother can you spare a dime             tt0072742
# 610                            who framed roger rabbit             tt0096438
# 705                                and justice for all             tt0078718
# 724                               bell book and candle             tt0051406
# 773                          the toxic avenger part ii             tt0098503
# 817                                      x the unknown             tt0049967
# 819                                   steal this movie             tt0161216
#
#                                             imdb_title  imdb_year
# 14                              steal big steal little 1995.00000
# 23                           die hard with a vengeance 1995.00000
# 80   the englishman who went up a hill but came dow... 1995.00000
# 107                                       bye bye love 1995.00000
# 215                                     shall we dance 1937.00000
# 278                                               mash 1970.00000
# 316                                      that darn cat 1997.00000
# 343                                       mrs dalloway 1997.00000
# 374                                   the players club 1998.00000
# 431                               next stop wonderland 1998.00000
# 435                          why do fools fall in love 1998.00000
# 448                                       say anything 1989.00000
# 450                                   about last night 1986.00000
# 478                             the karate kid part ii 1986.00000
# 527                                run silent run deep 1958.00000
# 566                            with friends like these 1998.00000
# 609                       brother can you spare a dime 1975.00000
# 610                            who framed roger rabbit 1988.00000
# 705                                and justice for all 1979.00000
# 724                               bell book and candle 1958.00000
# 773                          the toxic avenger part ii 1989.00000
# 817                                      x the unknown 1956.00000
# 819                                   steal this movie 2000.00000

# %%
match_without_numbers = pd.merge(unmatched_experiments, imdb_to_match, 
                              left_on=['no_numbers', 'year'],
                              right_on=['imdb_title', 'imdb_year'],
                              how='left')

match_without_numbers = match_without_numbers[match_without_numbers['tconst'] != '<NA>']
print("Found matches for ")
print(len(match_without_numbers))
print("movies")
match_without_numbers
# Out:
# Found matches for
# 0
# movies
# Empty DataFrame
# Columns: [movie_id, title, year, with_article, without_article, no_punctuation, no_numbers, tconst, imdb_title, imdb_year]
# Index: []

# %%
unmatched_movie_ids = list(unmatched['movie_id'])
matched_with_article_movie_ids = list(match_with_article['movie_id'])
matched_without_article_movie_ids = list(match_without_article['movie_id'])
matched_without_punctuation_movie_ids = list(match_without_punctuation['movie_id'])
print(len(unmatched_movie_ids))
print(len(matched_with_article_movie_ids))
print(len(matched_without_article_movie_ids))
print(len(matched_without_punctuation_movie_ids))
# Out:
# 833
# 7
# 9
# 23
# left to match:
# 794

# %%
left_to_match = set(unmatched_movie_ids) - set(matched_with_article_movie_ids) - set(matched_without_article_movie_ids) - set(matched_without_punctuation_movie_ids)
print("left to match:")
print(len(left_to_match))

unmatched = unmatched[unmatched['movie_id'].isin(list(left_to_match))]
unmatched.shape
# Out:
# (794, 12)

# %%
unmatched
# Out:
#       movie_id                                          title  \
# 27          28                                     persuasion
# 29          30  shanghai triad (yao a yao yao dao waipo qiao)
# 31          32                                 twelve monkeys
# 46          47                                  seven (se7en)
# 51          51                                 guardian angel
# ...        ...                                            ...
# 3870      3904                            uninvited guest, an
# 3873      3907                     the prince of central park
# 3880      3914                         the broken hearts club
# 3886      3920   faraway, so close (in weiter ferne, so nah!)
# 3901      3935                                         kronos
#
#                      genres  year tconst  averageRating  numVotes titleType  \
# 27                  romance  1995      0        0.00000   0.00000         0
# 29                    drama  1995      0        0.00000   0.00000         0
# 31             drama sci-fi  1995      0        0.00000   0.00000         0
# 46           crime thriller  1995      0        0.00000   0.00000         0
# 51    action drama thriller  1994      0        0.00000   0.00000         0
# ...                     ...   ...    ...            ...       ...       ...
# 3870                  drama  2000      0        0.00000   0.00000         0
# 3873                  drama  1999      0        0.00000   0.00000         0
# 3880                  drama  2000      0        0.00000   0.00000         0
# 3886          drama fantasy  1993      0        0.00000   0.00000         0
# 3901                 horror  1973      0        0.00000   0.00000         0
#
#      originalTitle isAdult runtimeMinutes imdb_genres
# 27               0       0              0           0
# 29               0       0              0           0
# 31               0       0              0           0
# 46               0       0              0           0
# 51               0       0              0           0
# ...            ...     ...            ...         ...
# 3870             0       0              0           0
# 3873             0       0              0           0
# 3880             0       0              0           0
# 3886             0       0              0           0
# 3901             0       0              0           0
#
# [794 rows x 12 columns]

# %%
# let's remove things in brackets 

unmatched_experiments['no_brackets'] = ''

for index, row in unmatched_experiments.iterrows(): 
    # for those who have 'the' at the beginning of the title, remove it 
    title = row['title']
    if ('(' in title): 
        no_brackets = title[: title.index('(')-1]
        unmatched_experiments.at[index, 'no_brackets'] = no_brackets
    
unmatched_experiments = unmatched_experiments.astype({'no_brackets': 'string'})

# %%
match_without_brackets = pd.merge(unmatched_experiments, imdb_to_match, 
                              left_on=['no_brackets', 'year'],
                              right_on=['imdb_title', 'imdb_year'],
                              how='left')

match_without_brackets = match_without_brackets[match_without_brackets['tconst'] != '<NA>']

print("Found matches for ")
print(len(match_without_brackets))
print("movies")
match_without_brackets
# Out:
# Found matches for
# 109
# movies
#      movie_id                                          title  year  \
# 1          30  shanghai triad (yao a yao yao dao waipo qiao)  1995
# 7          68                    french twist (gazon maudit)  1995
# 10         82                       antonia's line (antonia)  1995
# 13        106            nobody loves me (keiner liebt mich)  1994
# 27        213        burnt by the sun (utomlyonnye solntsem)  1994
# ..        ...                                            ...   ...
# 796      3800         criminal lovers (les amants criminels)  1999
# 803      3832       black sabbath (tre volti della paura, i)  1963
# 813      3867            all the rage (a.k.a. it's the rage)  1999
# 821      3892                             anatomy (anatomie)  2000
# 823      3902              goya in bordeaux (goya en bodeos)  1999
#
#                                           with_article without_article  \
# 1    the shanghai triad (yao a yao yao dao waipo qiao)
# 7                      the french twist (gazon maudit)
# 10                        the antonia's line (antonia)
# 13             the nobody loves me (keiner liebt mich)
# 27         the burnt by the sun (utomlyonnye solntsem)
# ..                                                 ...             ...
# 796         the criminal lovers (les amants criminels)
# 803       the black sabbath (tre volti della paura, i)
# 813            the all the rage (a.k.a. it's the rage)
# 821                             the anatomy (anatomie)
# 823              the goya in bordeaux (goya en bodeos)
#
#                                   no_punctuation no_numbers       no_brackets  \
# 1    shanghai triad yao a yao yao dao waipo qiao               shanghai triad
# 7                      french twist gazon maudit                 french twist
# 10                         antonias line antonia               antonia's line
# 13             nobody loves me keiner liebt mich              nobody loves me
# 27         burnt by the sun utomlyonnye solntsem             burnt by the sun
# ..                                           ...        ...               ...
# 796         criminal lovers les amants criminels              criminal lovers
# 803        black sabbath tre volti della paura i                black sabbath
# 813                all the rage aka its the rage                 all the rage
# 821                             anatomy anatomie                      anatomy
# 823              goya in bordeaux goya en bodeos             goya in bordeaux
#
#         tconst        imdb_title  imdb_year
# 1    tt0115012    shanghai triad 1995.00000
# 7    tt0113149      french twist 1995.00000
# 10   tt0112379    antonia's line 1995.00000
# 13   tt0110251   nobody loves me 1994.00000
# 27   tt0111579  burnt by the sun 1994.00000
# ..         ...               ...        ...
# 796  tt0205735   criminal lovers 1999.00000
# 803  tt0057603     black sabbath 1963.00000
# 813  tt0176426      all the rage 1999.00000
# 821  tt0187696           anatomy 2000.00000
# 823  tt0210717  goya in bordeaux 1999.00000
#
# [109 rows x 11 columns]

# %%
left_to_match = set(left_to_match) - set(match_without_brackets['movie_id'])

# %%
len(left_to_match)
# Out:
# 685

# %%
unmatched = unmatched[unmatched['movie_id'].isin(list(left_to_match))]

# %%
# a lot of these don't match because of mismatched years 
imdb_full[imdb_full['title'] == 'a little princess']
# Out:
#             tconst  averageRating  numVotes titleType              title  \
# 2244     tt0008196        6.20000       692     movie  a little princess
# 76572    tt0113670        7.60000     34066     movie  a little princess
# 241761  tt11414492        6.90000       185     movie  a little princess
#
#             originalTitle isAdult  year runtimeMinutes           imdb_genres
# 2244    A Little Princess       0  1917             62                 Drama
# 76572   A Little Princess       0  1995             97  Drama,Family,Fantasy
# 241761  A Little Princess       0  2019            104                 Drama

# %%
import string 
from string import digits 
from string import punctuation



unmatched_experiments = unmatched.copy(deep='True')
# unmatched_experiments['with_a'] = ''
unmatched_experiments['without_a'] = ''
unmatched_experiments['without_an'] = ''
# unmatched_experiments['with_an'] = ''
unmatched_experiments['inside_brackets'] = ''

for index, row in unmatched_experiments.iterrows(): 
    # for those who have 'a' at the beginning of the title, remove it 
    title = row['title']
    if title[-3:] == ', a': 
        unmatched_experiments.at[index, 'without_a'] = 'a ' + title[:-3]
    # for those who don't have 'a' at the beginning, add it on 
    # else: 
    #     unmatched_experiments.at[index, 'with_a'] = 'a ' + title[:-3]

    if title[-4:] == ', an': 
        unmatched_experiments.at[index, 'without_an'] = 'an ' + title[:-4]
    # for those who don't have 'an' at the beginning, add it on 
    # else: 
    #     unmatched_experiments.at[index, 'with_an'] = 'an ' + title[:-3]

    
    if ('(' in title and ')' in title):
        inside_brackets = title[title.index('(')+1: title.index(')')]
        unmatched_experiments.at[index, 'inside_brackets'] = inside_brackets

unmatched_experiments = unmatched_experiments.astype({'without_a': 'string',
                                                      'without_an': 'string',
                                                      'inside_brackets' : 'string'})

unmatched_experiments = unmatched_experiments.drop(columns=['genres', 'tconst', 'averageRating', 'numVotes', 'titleType', 'originalTitle', 'isAdult', 'runtimeMinutes', 'imdb_genres'])

# %%
match_without_a = pd.merge(unmatched_experiments, imdb_to_match, 
                              left_on=['without_a', 'year'],
                              right_on=['imdb_title', 'imdb_year'],
                              how='left')

match_without_a = match_without_a[match_without_a['tconst'] != '<NA>']
print("Found matches for ")
print(len(match_without_a))
print("movies")
match_without_a
# Out:
# Found matches for
# 77
# movies
#      movie_id                          title  year  \
# 20        207          walk in the clouds, a  1995
# 26        239                 goofy movie, a  1995
# 33        258  kid in king arthur's court, a  1995
# 35        262             little princess, a  1995
# 44        295     pyromaniac's love story, a  1995
# ..        ...                            ...   ...
# 569      3350           raisin in the sun, a  1961
# 581      3405           night to remember, a  1958
# 594      3475            place in the sun, a  1951
# 623      3640            king in new york, a  1957
# 676      3874           couch in new york, a  1996
#
#                         without_a without_an inside_brackets     tconst  \
# 20           a walk in the clouds                             tt0114887
# 26                  a goofy movie                             tt0113198
# 33   a kid in king arthur's court                             tt0113538
# 35              a little princess                             tt0113670
# 44      a pyromaniac's love story                             tt0114210
# ..                            ...        ...             ...        ...
# 569           a raisin in the sun                             tt0055353
# 581           a night to remember                             tt0051994
# 594            a place in the sun                             tt0043924
# 623            a king in new york                             tt0050598
# 676           a couch in new york                             tt0118018
#
#                        imdb_title  imdb_year
# 20           a walk in the clouds 1995.00000
# 26                  a goofy movie 1995.00000
# 33   a kid in king arthur's court 1995.00000
# 35              a little princess 1995.00000
# 44      a pyromaniac's love story 1995.00000
# ..                            ...        ...
# 569           a raisin in the sun 1961.00000
# 581           a night to remember 1958.00000
# 594            a place in the sun 1951.00000
# 623            a king in new york 1957.00000
# 676           a couch in new york 1996.00000
#
# [77 rows x 9 columns]

# %%
match_without_an = pd.merge(unmatched_experiments, imdb_to_match, 
                              left_on=['without_an', 'year'],
                              right_on=['imdb_title', 'imdb_year'],
                              how='left')

match_without_an = match_without_an[match_without_an['tconst'] != '<NA>']
print("Found matches for ")
print(len(match_without_an))
print("movies")
match_without_an
# Out:
# Found matches for
# 10
# movies
#      movie_id                                       title  year without_a  \
# 16        148                   awfully big adventure, an  1995
# 167       900                       american in paris, an  1951
# 168       932                      affair to remember, an  1957
# 248      1321             american werewolf in london, an  1981
# 320      1853  alan smithee film: burn hollywood burn, an  1997
# 361      2141                           american tail, an  1986
# 362      2142         american tail: fievel goes west, an  1991
# 447      2690                           ideal husband, an  1999
# 448      2690                           ideal husband, an  1999
# 469      2793              american werewolf in paris, an  1997
#
#                                     without_an inside_brackets     tconst  \
# 16                    an awfully big adventure                  tt0112427
# 167                       an american in paris                  tt0043278
# 168                      an affair to remember                  tt0050105
# 248             an american werewolf in london                  tt0082010
# 320  an alan smithee film: burn hollywood burn                  tt0118577
# 361                           an american tail                  tt0090633
# 362         an american tail: fievel goes west                  tt0101329
# 447                           an ideal husband                  tt0122541
# 448                           an ideal husband                  tt0160395
# 469              an american werewolf in paris                  tt0118604
#
#                                     imdb_title  imdb_year
# 16                    an awfully big adventure 1995.00000
# 167                       an american in paris 1951.00000
# 168                      an affair to remember 1957.00000
# 248             an american werewolf in london 1981.00000
# 320  an alan smithee film: burn hollywood burn 1997.00000
# 361                           an american tail 1986.00000
# 362         an american tail: fievel goes west 1991.00000
# 447                           an ideal husband 1999.00000
# 448                           an ideal husband 1999.00000
# 469              an american werewolf in paris 1997.00000

# %%
match_inside_brackets = pd.merge(unmatched_experiments, imdb_to_match, 
                              left_on=['inside_brackets', 'year'],
                              right_on=['imdb_title', 'imdb_year'],
                              how='left')

match_inside_brackets = match_inside_brackets[match_inside_brackets['tconst'] != '<NA>']
print("Found matches for ")
print(len(match_inside_brackets))
print("movies")
match_inside_brackets
# Out:
# Found matches for
# 20
# movies
#      movie_id                                              title  year  \
# 2          47                                      seven (se7en)  1995
# 4          58                          postino, il (the postman)  1994
# 38        269                       my crazy life (mi vida loca)  1993
# 76        561                         killer (bulletproof heart)  1994
# 85        582                             metisse (café au lait)  1993
# 110       681                      clean slate (coup de torchon)  1981
# 118       718                      visitors, the (les visiteurs)  1993
# 124       735                cemetery man (dellamorte dellamore)  1994
# 134       773                 touki bouki (journey of the hyena)  1973
# 139       793  my life and times with antonin artaud (en comp...  1993
# 176       989                 schlafes bruder (brother of sleep)  1995
# 215      1155                      invitation, the (zaproszenie)  1986
# 298      1734                   my life in pink (ma vie en rose)  1997
# 433      2595                          photographer (fotoamator)  1998
# 450      2696                dinner game, the (le dîner de cons)  1998
# 486      2869                    separation, the (la séparation)  1994
# 501      2934                  love bewitched, a (el amor brujo)  1986
# 539      3192                             terrorist, the (malli)  1998
# 581      3407  carriers are waiting, the (les convoyeurs atte...  1999
# 629      3655                        blow-out (la grande bouffe)  1973
#
#     without_a without_an                inside_brackets     tconst  \
# 2                                                 se7en  tt0114369
# 4                                           the postman  tt0110877
# 38                                         mi vida loca  tt0107566
# 76                                    bulletproof heart  tt0110259
# 85                                         café au lait  tt0107642
# 110                                     coup de torchon  tt0082206
# 118                                       les visiteurs  tt0108500
# 124                                dellamorte dellamore  tt0109592
# 134                                journey of the hyena  tt0070820
# 139                       en compagnie d'antonin artaud  tt0106810
# 176                                    brother of sleep  tt0114354
# 215                                         zaproszenie  tt0092281
# 298                                      ma vie en rose  tt0119590
# 433                                          fotoamator  tt0188996
# 450                                    le dîner de cons  tt0119038
# 486                                       la séparation  tt0111342
# 501                                       el amor brujo  tt0090636
# 539                                               malli  tt0293385
# 581                            les convoyeurs attendent  tt0201538
# 629                                    la grande bouffe  tt0070130
#
#                         imdb_title  imdb_year
# 2                            se7en 1995.00000
# 4                      the postman 1994.00000
# 38                    mi vida loca 1993.00000
# 76               bulletproof heart 1994.00000
# 85                    café au lait 1993.00000
# 110                coup de torchon 1981.00000
# 118                  les visiteurs 1993.00000
# 124           dellamorte dellamore 1994.00000
# 134           journey of the hyena 1973.00000
# 139  en compagnie d'antonin artaud 1993.00000
# 176               brother of sleep 1995.00000
# 215                    zaproszenie 1986.00000
# 298                 ma vie en rose 1997.00000
# 433                     fotoamator 1998.00000
# 450               le dîner de cons 1998.00000
# 486                  la séparation 1994.00000
# 501                  el amor brujo 1986.00000
# 539                          malli 1998.00000
# 581       les convoyeurs attendent 1999.00000
# 629               la grande bouffe 1973.00000

# %%
left_to_match = set(left_to_match) - set(match_without_a['movie_id']) - set(match_without_an['movie_id']) - set(match_inside_brackets['movie_id'])
print("left to match:")
print(len(left_to_match))

unmatched = unmatched[unmatched['movie_id'].isin(list(left_to_match))]
# Out:
# left to match:
# 580

# %%
# movielens confessional, the (le confessionnal)
imdb_full[imdb_full['title'] == 'the confessional']
# Out:
#            tconst  averageRating  numVotes titleType             title  \
# 75872   tt0112714        7.40000      1588     movie  the confessional
# 214159  tt0860837        6.60000       110     movie  the confessional
# 325496  tt2047872        5.60000         5     short  the confessional
#
#            originalTitle isAdult  year runtimeMinutes             imdb_genres
# 75872   Le confessionnal       0  1995            100  Drama,Mystery,Thriller
# 214159  The Confessional       0  2009            117     Action,Comedy,Crime
# 325496  The Confessional       0  2011              5            Horror,Short

# %%
# movielens dumb & dumber
imdb_full[imdb_full['title'] == 'dumb and dumber']
# Out:
#           tconst  averageRating  numVotes titleType            title  \
# 73900  tt0109686        7.30000    374205     movie  dumb and dumber
#
#          originalTitle isAdult  year runtimeMinutes imdb_genres
# 73900  Dumb and Dumber       0  1994            107      Comedy

# %%
# movielens the boys of st. vincent but 1993
imdb_full[imdb_full['title'] == 'the boys of st. vincent']
# Out:
#           tconst  averageRating  numVotes titleType                    title  \
# 71705  tt0106473        7.60000      1736   tvMovie  the boys of st. vincent
#
#                  originalTitle isAdult  year runtimeMinutes imdb_genres
# 71705  The Boys of St. Vincent       0  1992             93       Drama

# %%
# movielens colonel chabert, le
imdb_full[imdb_full['title'] == 'le colonel chabert']
# Out:
#           tconst  averageRating  numVotes titleType               title  \
# 98580  tt0164006        7.10000       113     movie  le colonel chabert
#
#             originalTitle isAdult  year runtimeMinutes imdb_genres
# 98580  Le colonel Chabert       0  1943            102       Drama

# %%
# remove ALL POSSIBLE ARTICLES FROM ALL TITLES AND MATCH LIKE THAT 
# MATCH WITH + - 1 YEAR

# %%
# movielens rent-a-cop	
imdb_full[imdb_full['title'] == 'the naked gun 2 1/2']
# Out:
# Empty DataFrame
# Columns: [tconst, averageRating, numVotes, titleType, title, originalTitle, isAdult, year, runtimeMinutes, imdb_genres]
# Index: []

# %%
unmatched.to_csv('.unmatched.csv', index=False)

# %%
# match with year + 1 - 1 

imdb_to_match['year+1'] = imdb_to_match['imdb_year'] + 1
imdb_to_match['year-1'] = imdb_to_match['imdb_year'] - 1

# %%
imdb_to_match.head()
# Out:
#       tconst              imdb_title  imdb_year  year+1  year-1
# 0  tt0000001              carmencita       1894    1895    1893
# 1  tt0000002  le clown et ses chiens       1892    1893    1891
# 2  tt0000003          pauvre pierrot       1892    1893    1891
# 3  tt0000004             un bon bock       1892    1893    1891
# 4  tt0000005        blacksmith scene       1893    1894    1892

# %%
unmatched_experiments = unmatched.copy(deep=True)
unmatched_experiments = unmatched_experiments.astype({'title': 'string'})
unmatched_experiments = unmatched_experiments.drop(columns=['genres', 'tconst', 'averageRating', 'numVotes', 'titleType', 'originalTitle', 'isAdult', 'runtimeMinutes', 'imdb_genres'])

# %%
unmatched_experiments
# Out:
#       movie_id                                         title  year
# 27          28                                    persuasion  1995
# 31          32                                twelve monkeys  1995
# 51          51                                guardian angel  1994
# 59          59          confessional, the (le confessionnal)  1995
# 73          73                               misérables, les  1995
# ...        ...                                           ...   ...
# 3870      3904                           uninvited guest, an  2000
# 3873      3907                    the prince of central park  1999
# 3880      3914                        the broken hearts club  2000
# 3886      3920  faraway, so close (in weiter ferne, so nah!)  1993
# 3901      3935                                        kronos  1973
#
# [580 rows x 3 columns]

# %%
year_plus_one_match = pd.merge(unmatched_experiments, imdb_to_match, 
                              left_on=['title', 'year'],
                              right_on=['imdb_title', 'year+1'],
                              how='left')

year_plus_one_match = year_plus_one_match[year_plus_one_match['tconst'] != '<NA>']
print("Found matches for ")
print(len(year_plus_one_match))
print("movies")
year_plus_one_match
# Out:
# Found matches for
# 110
# movies
#      movie_id                        title  year     tconst  \
# 8         121      the boys of st. vincent  1993  tt0106473
# 18        224             don juan demarco  1995  tt0112883
# 23        243                        gordy  1995  tt0113199
# 36        298                pushing hands  1992  tt0105652
# 37        301                picture bride  1995  tt0114129
# ..        ...                          ...   ...        ...
# 549      3771  the golden voyage of sinbad  1974  tt0071569
# 553      3789               the pawnbroker  1965  tt0059575
# 555      3799       pokémon the movie 2000  2000  tt0210234
# 560      3819                      tampopo  1986  tt0092048
# 572      3883  catfish in black bean sauce  2000  tt0162903
#
#                       imdb_title  imdb_year     year+1     year-1
# 8        the boys of st. vincent 1992.00000 1993.00000 1991.00000
# 18              don juan demarco 1994.00000 1995.00000 1993.00000
# 23                         gordy 1994.00000 1995.00000 1993.00000
# 36                 pushing hands 1991.00000 1992.00000 1990.00000
# 37                 picture bride 1994.00000 1995.00000 1993.00000
# ..                           ...        ...        ...        ...
# 549  the golden voyage of sinbad 1973.00000 1974.00000 1972.00000
# 553               the pawnbroker 1964.00000 1965.00000 1963.00000
# 555       pokémon the movie 2000 1999.00000 2000.00000 1998.00000
# 560                      tampopo 1985.00000 1986.00000 1984.00000
# 572  catfish in black bean sauce 1999.00000 2000.00000 1998.00000
#
# [110 rows x 8 columns]

# %%
year_minus_one_match = pd.merge(unmatched_experiments, imdb_to_match, 
                              left_on=['title', 'year'],
                              right_on=['imdb_title', 'year-1'],
                              how='left')

year_minus_one_match = year_minus_one_match[year_minus_one_match['tconst'] != '<NA>']
print("Found matches for ")
print(len(year_minus_one_match))
print("movies")
year_minus_one_match
# Out:
# Found matches for
# 82
# movies
#      movie_id              title  year     tconst         imdb_title  \
# 11        128     jupiter's wife  1994  tt0110217     jupiter's wife
# 14        157     canadian bacon  1994  tt0109370     canadian bacon
# 15        183       mute witness  1994  tt0110604       mute witness
# 20        230  dolores claiborne  1994  tt0109642  dolores claiborne
# 24        248         houseguest  1994  tt0110066         houseguest
# ..        ...                ...   ...        ...                ...
# 506      3561    stacy's knights  1982  tt0084723    stacy's knights
# 508      3567         bossa nova  1999  tt0180837         bossa nova
# 542      3721             trixie  1999  tt0162711             trixie
# 544      3728     one false move  1991  tt0102592     one false move
# 554      3777        nekromantik  1987  tt0093608        nekromantik
#
#      imdb_year     year+1     year-1
# 11  1995.00000 1996.00000 1994.00000
# 14  1995.00000 1996.00000 1994.00000
# 15  1995.00000 1996.00000 1994.00000
# 20  1995.00000 1996.00000 1994.00000
# 24  1995.00000 1996.00000 1994.00000
# ..         ...        ...        ...
# 506 1983.00000 1984.00000 1982.00000
# 508 2000.00000 2001.00000 1999.00000
# 542 2000.00000 2001.00000 1999.00000
# 544 1992.00000 1993.00000 1991.00000
# 554 1988.00000 1989.00000 1987.00000
#
# [82 rows x 8 columns]

# %%
left_to_match = set(left_to_match) - set(year_minus_one_match['movie_id']) - set(year_plus_one_match['movie_id'])
print("left to match:")
print(len(left_to_match))

unmatched = unmatched[unmatched['movie_id'].isin(list(left_to_match))]
# Out:
# left to match:
# 393

# %%
unmatched['title'] = unmatched['title'].replace({'twelve': '12'})

# %%
unmatched.head()
# Out:
#     movie_id                                 title                 genres  \
# 27        28                            persuasion                romance
# 31        32                        twelve monkeys           drama sci-fi
# 51        51                        guardian angel  action drama thriller
# 59        59  confessional, the (le confessionnal)          drama mystery
# 73        73                       misérables, les          drama musical
#
#     year  tconst  averageRating  numVotes  titleType  originalTitle  isAdult  \
# 27  1995       0        0.00000   0.00000          0              0        0
# 31  1995       0        0.00000   0.00000          0              0        0
# 51  1994       0        0.00000   0.00000          0              0        0
# 59  1995       0        0.00000   0.00000          0              0        0
# 73  1995       0        0.00000   0.00000          0              0        0
#
#     runtimeMinutes  imdb_genres
# 27               0            0
# 31               0            0
# 51               0            0
# 59               0            0
# 73               0            0

# %%
unmatched.at[31,'title']='12 monkeys'

# %%
unmatched.head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/yw/ylqvp3zj44sd953rbzx5g3gh0000gn/T/ipykernel_56035/1026347766.py in <module>
# ----> 1 unmatched.head(20)
#
# NameError: name 'unmatched' is not defined

# %%
def replace_ampersand(title): 
    if ('&' in title):
        title = title.replace('&', 'and')
    return title

unmatched['title'] = unmatched['title'].apply(lambda x: replace_ampersand(x))

# %%
unmatched[unmatched['title'] == 'dumb and dumber']
# Out:
#      movie_id            title  genres  year  tconst  averageRating  numVotes  \
# 231       231  dumb and dumber  comedy  1994       0        0.00000   0.00000
#
#      titleType  originalTitle  isAdult  runtimeMinutes  imdb_genres
# 231          0              0        0               0            0

# %%
unmatched_experiments = unmatched.copy(deep=True)
unmatched_experiments = unmatched_experiments.astype({'title': 'string'})
unmatched_experiments = unmatched_experiments.drop(columns=['genres', 'tconst', 'averageRating', 'numVotes', 'titleType', 'originalTitle', 'isAdult', 'runtimeMinutes', 'imdb_genres'])

new_matches = pd.merge(unmatched_experiments, imdb_to_match, 
                              left_on=['title', 'year'],
                              right_on=['imdb_title', 'imdb_year'],
                              how='left')

new_matches = new_matches[new_matches['tconst'] != '<NA>']
print("Found matches for ")
print(len(new_matches))
print("movies")
new_matches
# Out:
# Found matches for
# 5
# movies
#      movie_id                                title  year     tconst  \
# 1          32                           12 monkeys  1995  tt0114746
# 15        231                      dumb and dumber  1994  tt0109686
# 230      2542  lock, stock and two smoking barrels  1998  tt0120735
# 259      2837                bedrooms and hallways  1998  tt0126810
# 385      3876                        jerry and tom  1998  tt0120867
#
#                               imdb_title  imdb_year     year+1     year-1
# 1                             12 monkeys 1995.00000 1996.00000 1994.00000
# 15                       dumb and dumber 1994.00000 1995.00000 1993.00000
# 230  lock, stock and two smoking barrels 1998.00000 1999.00000 1997.00000
# 259                bedrooms and hallways 1998.00000 1999.00000 1997.00000
# 385                        jerry and tom 1998.00000 1999.00000 1997.00000

# %%
left_to_match = set(left_to_match) - set(new_matches['movie_id'])
print("left to match:")
print(len(left_to_match))

unmatched = unmatched[unmatched['movie_id'].isin(list(left_to_match))]
# Out:
# left to match:
# 388

# %% [markdown]
# # Do everything again, but more efficiently

# %% [markdown]
# The discoveries I made are:
# * movielens puts articles at the end of the movie title, i.e. : contender, the
# * imdb puts articles at the start of the title: i.e. the contender
# * some of the articles I found are: the, an, l' , le , la, dir
# * movielens -> movieName (secondaryName) .... imdb -> movieName or secondaryName
# * movielens -> dumb & dumber ... imdb -> dumb and dumber
# * mismatch with punctuation and numbers
# * mismatch with years, sometimes the years are 1 year apart

# %%
# dataframes that I will be matching 

unmatched = movies_full.copy(deep=True)
imdb_to_match = imdb_full.copy(deep=True) 

unmatched = unmatched.astype({'title': 'string'})
imdb_to_match = imdb_to_match.astype({'tconst': 'string'})

# unmatched = unmatched.drop(columns=['genres', 'tconst', 'averageRating', 'numVotes', 'titleType', 'originalTitle', 'isAdult', 'runtimeMinutes', 'imdb_genres'])
imdb_to_match = imdb_to_match.drop(columns=['imdb_genres', 'averageRating', 'numVotes', 'titleType', 'originalTitle', 'isAdult', 'runtimeMinutes', 'imdb_genres'])

unmatched.shape
# Out:
# (3883, 4)

# %%
import string 
from string import punctuation

def remove_movielens_articles(title):
    new_title = title
    articles = {', the', ', a', ', an', ', le', ', la', ', l\'', ', el', ', dir', ', der'}
    for article in articles: 
        if article in title: 
            new_title = title[:title.index(article)]
    return new_title 

def remove_imdb_articles(title): 
    new_title = title
    articles = {'the ', 'a ', 'an ', 'le ', 'la ', 'l\' ', 'el ', 'dir', 'der'}
    for article in articles: 
        if article in title: 
            new_title = title[title.index(article) + len(article):] 
    return new_title

def remove_punctuation(title): 
    new_title = title
    if (any(p in title for p in punctuation)):
        new_title = title.translate(str.maketrans('', '', string.punctuation))
    return new_title 

def remove_numbers(title):
    no_digits = []
    for i in title:
        if not i.isdigit():
            no_digits.append(i)
    return ''.join(no_digits)

def remove_secondary(title):
    new_title = title
    if ('(' in title and ')' in title):
        new_title = title[: title.index('(')-1]
    
    return new_title 

def extract_secondary(title):
    new_title = title
    if ('(' in title and ')' in title):
        new_title = title[title.index('(') + 1: title.index(')')]
    return new_title

# %%
unmatched['stripped_title'] = ''

for index, row in unmatched.iterrows(): 
    title = row['title']
    no_article = remove_movielens_articles(title)    
    no_punctuation = remove_punctuation('.'.join(no_article))
    no_numbers = remove_numbers(''.join(no_punctuation))
    unmatched.at[index, 'stripped_title'] = no_numbers
    
imdb_to_match['stripped_title'] = ''

for index, row in imdb_to_match.iterrows(): 
    title = row['title']
    no_article = remove_imdb_articles(''.join(title))    
    no_punctuation = remove_punctuation('.'.join(no_article))
    no_numbers = remove_numbers(''.join(no_punctuation))
    imdb_to_match.at[index, 'stripped_title'] = no_numbers

# %%
unmatched['no_secondary'] = ''
unmatched['only_secondary'] = ''

for index, row in unmatched.iterrows(): 
    title = row['title']
    no_article = remove_movielens_articles(title)
    no_secondary = remove_secondary(''.join(no_article))
    only_secondary = extract_secondary(''.join(no_article))
    unmatched.at[index, 'no_secondary'] = no_secondary
    unmatched.at[index, 'only_secondary'] = only_secondary
        

imdb_to_match['no_secondary'] = ''
imdb_to_match['only_secondary'] = ''

for index, row in imdb_to_match.iterrows(): 
    title = row['title']
    no_article = remove_imdb_articles(''.join(title))
    
    no_secondary = remove_secondary(''.join(no_article))
    only_secondary = extract_secondary(''.join(no_article))
    imdb_to_match.at[index, 'no_secondary'] = no_secondary
    imdb_to_match.at[index, 'only_secondary'] = only_secondary

# %%
imdb_to_match = imdb_to_match.astype({'stripped_title': 'string',
                                      'no_secondary': 'string',
                                      'only_secondary': 'string',})

unmatched = unmatched.astype({'stripped_title': 'string',
                                      'no_secondary': 'string',
                                      'only_secondary': 'string',})

unmatched = unmatched.drop(columns = 'genres')

# %%
match = pd.merge(unmatched, imdb_to_match, on=['stripped_title', 'year'])
unmatched_ids = set(unmatched['movie_id']) - set(match['movie_id'])
unmatched = unmatched[unmatched['movie_id'].isin(list(unmatched_ids))]
# unmatched = unmatched.drop(columns=['stripped_title'])
# unmatched = unmatched.drop(columns=['title'])
unmatched
# Out:
#       movie_id                                          title  year  \
# 4            5                    father of the bride part ii  1995
# 23          24                                         powder  1995
# 27          28                                     persuasion  1995
# 29          30  shanghai triad (yao a yao yao dao waipo qiao)  1995
# 31          32                                 twelve monkeys  1995
# ...        ...                                            ...   ...
# 3865      3935                                         kronos  1973
# 3866      3936                      phantom of the opera, the  1943
# 3875      3945                             digimon: the movie  2000
# 3878      3948                               meet the parents  2000
# 3879      3949                            requiem for a dream  2000
#
#                                    stripped_title  \
# 4                     father of the bride part ii
# 23                                         powder
# 27                                     persuasion
# 29    shanghai triad yao a yao yao dao waipo qiao
# 31                                 twelve monkeys
# ...                                           ...
# 3865                                       kronos
# 3866                         phantom of the opera
# 3875                            digimon the movie
# 3878                             meet the parents
# 3879                          requiem for a dream
#
#                      no_secondary                only_secondary
# 4     father of the bride part ii   father of the bride part ii
# 23                         powder                        powder
# 27                     persuasion                    persuasion
# 29                 shanghai triad  yao a yao yao dao waipo qiao
# 31                 twelve monkeys                twelve monkeys
# ...                           ...                           ...
# 3865                       kronos                        kronos
# 3866         phantom of the opera          phantom of the opera
# 3875           digimon: the movie            digimon: the movie
# 3878             meet the parents              meet the parents
# 3879          requiem for a dream           requiem for a dream
#
# [1127 rows x 6 columns]

# %%
only_secondary_match = unmatched.copy(deep=True)
only_secondary_match = pd.merge(only_secondary_match, imdb_to_match, on=['only_secondary', 'year'])

only_secondary_match
# Out:
#    movie_id                                            title_x  year  \
# 0        47                                      seven (se7en)  1995
# 1       561                         killer (bulletproof heart)  1994
# 2       582                             metisse (café au lait)  1993
# 3       681                      clean slate (coup de torchon)  1981
# 4       735                cemetery man (dellamorte dellamore)  1994
# 5       793  my life and times with antonin artaud (en comp...  1993
# 6       989                 schlafes bruder (brother of sleep)  1995
# 7      2595                          photographer (fotoamator)  1998
#
#                                     stripped_title_x  \
# 0                                         seven seen
# 1                           killer bulletproof heart
# 2                               metisse café au lait
# 3                        clean slate coup de torchon
# 4                  cemetery man dellamorte dellamore
# 5  my life and times with antonin artaud en compa...
# 6                   schlafes bruder brother of sleep
# 7                            photographer fotoamator
#
#                           no_secondary_x                 only_secondary  \
# 0                                  seven                          se7en
# 1                                 killer              bulletproof heart
# 2                                metisse                   café au lait
# 3                            clean slate                coup de torchon
# 4                           cemetery man           dellamorte dellamore
# 5  my life and times with antonin artaud  en compagnie d'antonin artaud
# 6                        schlafes bruder               brother of sleep
# 7                           photographer                     fotoamator
#
#       tconst                        title_y              stripped_title_y  \
# 0  tt0114369                          se7en                          seen
# 1  tt0110259              bulletproof heart             bulletproof heart
# 2  tt0107642                   café au lait                  café au lait
# 3  tt0082206                coup de torchon               coup de torchon
# 4  tt0109592           dellamorte dellamore          dellamorte dellamore
# 5  tt0106810  en compagnie d'antonin artaud  en compagnie dantonin artaud
# 6  tt0114354               brother of sleep              brother of sleep
# 7  tt0188996                     fotoamator                    fotoamator
#
#                   no_secondary_y
# 0                          se7en
# 1              bulletproof heart
# 2                   café au lait
# 3                coup de torchon
# 4           dellamorte dellamore
# 5  en compagnie d'antonin artaud
# 6               brother of sleep
# 7                     fotoamator

# %%
no_secondary_match = unmatched.copy(deep=True)
no_secondary_match = pd.merge(no_secondary_match, imdb_to_match, on=['no_secondary', 'year'])
no_secondary_match
# Out:
#     movie_id                                        title_x  year  \
# 0         30  shanghai triad (yao a yao yao dao waipo qiao)  1995
# 1         68                    french twist (gazon maudit)  1995
# 2         82                       antonia's line (antonia)  1995
# 3        106            nobody loves me (keiner liebt mich)  1994
# 4        142                               shadows (cienie)  1988
# ..       ...                                            ...   ...
# 78      3761    blood in, blood out (a.k.a. bound by honor)  1993
# 79      3787                                shower (xizhao)  1999
# 80      3800         criminal lovers (les amants criminels)  1999
# 81      3832       black sabbath (tre volti della paura, i)  1963
# 82      3892                             anatomy (anatomie)  2000
#
#                                stripped_title_x         no_secondary  \
# 0   shanghai triad yao a yao yao dao waipo qiao       shanghai triad
# 1                     french twist gazon maudit         french twist
# 2                         antonias line antonia       antonia's line
# 3             nobody loves me keiner liebt mich      nobody loves me
# 4                                shadows cienie              shadows
# ..                                          ...                  ...
# 78        blood in blood out aka bound by honor  blood in, blood out
# 79                                shower xizhao               shower
# 80         criminal lovers les amants criminels      criminal lovers
# 81        black sabbath tre volti della paura i        black sabbath
# 82                             anatomy anatomie              anatomy
#
#                 only_secondary_x     tconst              title_y  \
# 0   yao a yao yao dao waipo qiao  tt0115012       shanghai triad
# 1                   gazon maudit  tt0113149         french twist
# 2                        antonia  tt0112379       antonia's line
# 3              keiner liebt mich  tt0110251      nobody loves me
# 4                         cienie  tt0095804   out of the shadows
# ..                           ...        ...                  ...
# 78         a.k.a. bound by honor  tt0106469  blood in, blood out
# 79                        xizhao  tt0215369               shower
# 80          les amants criminels  tt0205735      criminal lovers
# 81      tre volti della paura, i  tt0057603        black sabbath
# 82                      anatomie  tt0187696              anatomy
#
#       stripped_title_y     only_secondary_y
# 0       shanghai triad       shanghai triad
# 1         french twist         french twist
# 2        antonias line       antonia's line
# 3      nobody loves me      nobody loves me
# 4              shadows              shadows
# ..                 ...                  ...
# 78  blood in blood out  blood in, blood out
# 79              shower               shower
# 80     criminal lovers      criminal lovers
# 81       black sabbath        black sabbath
# 82             anatomy              anatomy
#
# [83 rows x 10 columns]

# %%
unmatched
# Out:
#       movie_id                                          title  year  \
# 4            5                    father of the bride part ii  1995
# 23          24                                         powder  1995
# 27          28                                     persuasion  1995
# 29          30  shanghai triad (yao a yao yao dao waipo qiao)  1995
# 31          32                                 twelve monkeys  1995
# ...        ...                                            ...   ...
# 3865      3935                                         kronos  1973
# 3866      3936                      phantom of the opera, the  1943
# 3875      3945                             digimon: the movie  2000
# 3878      3948                               meet the parents  2000
# 3879      3949                            requiem for a dream  2000
#
#                                    stripped_title  \
# 4                     father of the bride part ii
# 23                                         powder
# 27                                     persuasion
# 29    shanghai triad yao a yao yao dao waipo qiao
# 31                                 twelve monkeys
# ...                                           ...
# 3865                                       kronos
# 3866                         phantom of the opera
# 3875                            digimon the movie
# 3878                             meet the parents
# 3879                          requiem for a dream
#
#                      no_secondary                only_secondary
# 4     father of the bride part ii   father of the bride part ii
# 23                         powder                        powder
# 27                     persuasion                    persuasion
# 29                 shanghai triad  yao a yao yao dao waipo qiao
# 31                 twelve monkeys                twelve monkeys
# ...                           ...                           ...
# 3865                       kronos                        kronos
# 3866         phantom of the opera          phantom of the opera
# 3875           digimon: the movie            digimon: the movie
# 3878             meet the parents              meet the parents
# 3879          requiem for a dream           requiem for a dream
#
# [1127 rows x 6 columns]

# %%
unmatched_ids = set(unmatched['movie_id']) - set(only_secondary_match['movie_id']) - set(no_secondary_match['movie_id'])
unmatched = unmatched[unmatched['movie_id'].isin(list(unmatched_ids))]

# %%
unmatched['year+1'] = unmatched['year'] + 1
unmatched['year-1'] = unmatched['year'] - 1
# Out:
# /Users/nutsa/.pyenv/versions/3.7.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/nutsa/.pyenv/versions/3.7.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
minus_year_match = unmatched.copy(deep=True)
minus_year_match = pd.merge(minus_year_match, imdb_to_match, left_on=['title', 'year-1'], right_on=['title', 'year'])
minus_year_match
# Out:
#     movie_id                        title  year_x  \
# 0        224             don juan demarco    1995
# 1        243                        gordy    1995
# 2        298                pushing hands    1992
# 3        301                picture bride    1995
# 4        322         swimming with sharks    1995
# ..       ...                          ...     ...
# 87      3687                  light years    1988
# 88      3799       pokémon the movie 2000    2000
# 89      3819                      tampopo    1986
# 90      3883  catfish in black bean sauce    2000
# 91      3925       stranger than paradise    1984
#
#                stripped_title_x               no_secondary_x  \
# 0              don juan demarco             don juan demarco
# 1                         gordy                        gordy
# 2                 pushing hands                pushing hands
# 3                 picture bride                picture bride
# 4          swimming with sharks         swimming with sharks
# ..                          ...                          ...
# 87                  light years                  light years
# 88           pokémon the movie        pokémon the movie 2000
# 89                      tampopo                      tampopo
# 90  catfish in black bean sauce  catfish in black bean sauce
# 91       stranger than paradise       stranger than paradise
#
#                only_secondary_x  year+1  year-1     tconst  year_y  \
# 0              don juan demarco    1996    1994  tt0112883    1994
# 1                         gordy    1996    1994  tt0113199    1994
# 2                 pushing hands    1993    1991  tt0105652    1991
# 3                 picture bride    1996    1994  tt0114129    1994
# 4          swimming with sharks    1996    1994  tt0114594    1994
# ..                          ...     ...     ...        ...     ...
# 87                  light years    1989    1987  tt3351342    1987
# 88       pokémon the movie 2000    2001    1999  tt0210234    1999
# 89                      tampopo    1987    1985  tt0092048    1985
# 90  catfish in black bean sauce    2001    1999  tt0162903    1999
# 91       stranger than paradise    1985    1983  tt0209182    1983
#
#         stripped_title_y        no_secondary_y      only_secondary_y
# 0                demarco               demarco               demarco
# 1                  gordy                 gordy                 gordy
# 2          pushing hands         pushing hands         pushing hands
# 3          picture bride         picture bride         picture bride
# 4   swimming with sharks  swimming with sharks  swimming with sharks
# ..                   ...                   ...                   ...
# 87           light years           light years           light years
# 88                movie             movie 2000            movie 2000
# 89               tampopo               tampopo               tampopo
# 90                 sauce                 sauce                 sauce
# 91              paradise              paradise              paradise
#
# [92 rows x 13 columns]

# %%
plus_year_match = unmatched.copy(deep=True)
plus_year_match = pd.merge(plus_year_match, imdb_to_match, left_on=['title', 'year+1'], right_on=['title', 'year'])
plus_year_match
# Out:
#     movie_id              title  year_x   stripped_title_x     no_secondary_x  \
# 0        128     jupiter's wife    1994      jupiters wife     jupiter's wife
# 1        157     canadian bacon    1994     canadian bacon     canadian bacon
# 2        183       mute witness    1994       mute witness       mute witness
# 3        230  dolores claiborne    1994  dolores claiborne  dolores claiborne
# 4        248         houseguest    1994         houseguest         houseguest
# ..       ...                ...     ...                ...                ...
# 63      3567         bossa nova    1999         bossa nova         bossa nova
# 64      3721             trixie    1999             trixie             trixie
# 65      3728     one false move    1991     one false move     one false move
# 66      3777        nekromantik    1987        nekromantik        nekromantik
# 67      3844    steel magnolias    1989    steel magnolias    steel magnolias
#
#      only_secondary_x  year+1  year-1     tconst  year_y   stripped_title_y  \
# 0      jupiter's wife    1995    1993  tt0110217    1995      jupiters wife
# 1      canadian bacon    1995    1993  tt0109370    1995              bacon
# 2        mute witness    1995    1993  tt0110604    1995       mute witness
# 3   dolores claiborne    1995    1993  tt0109642    1995  dolores claiborne
# 4          houseguest    1995    1993  tt0110066    1995         houseguest
# ..                ...     ...     ...        ...     ...                ...
# 63         bossa nova    2000    1998  tt0180837    2000               nova
# 64             trixie    2000    1998  tt0162711    2000             trixie
# 65     one false move    1992    1990  tt0102592    1992     one false move
# 66        nekromantik    1988    1986  tt0093608    1988        nekromantik
# 67    steel magnolias    1990    1988  tt0843875    1990          magnolias
#
#        no_secondary_y   only_secondary_y
# 0      jupiter's wife     jupiter's wife
# 1               bacon              bacon
# 2        mute witness       mute witness
# 3   dolores claiborne  dolores claiborne
# 4          houseguest         houseguest
# ..                ...                ...
# 63               nova               nova
# 64             trixie             trixie
# 65     one false move     one false move
# 66        nekromantik        nekromantik
# 67          magnolias          magnolias
#
# [68 rows x 13 columns]

# %%
unmatched_ids = set(unmatched['movie_id']) - set(plus_year_match['movie_id']) - set(minus_year_match['movie_id'])
unmatched = unmatched[unmatched['movie_id'].isin(list(unmatched_ids))]
unmatched.head(40)
# Out:
#      movie_id                                              title  year  \
# 4           5                        father of the bride part ii  1995
# 23         24                                             powder  1995
# 27         28                                         persuasion  1995
# 31         32                                     twelve monkeys  1995
# 35         36                                   dead man walking  1995
# 36         37                             across the sea of time  1995
# 45         46                      how to make an american quilt  1995
# 50         51                                     guardian angel  1994
# 55         56                            kids of the round table  1995
# 56         57                              home for the holidays  1995
# 57         58                          postino, il (the postman)  1994
# 60         61                                     eye for an eye  1996
# 62         63  don't be a menace to south central while drink...  1996
# 65         66                 lawnmower man 2: beyond cyberspace  1996
# 72         73                                    misérables, les  1995
# 82         83           once upon a time... when we were colored  1995
# 83         84                        last summer in the hamptons  1995
# 94         96                             in the bleak midwinter  1995
# 95         97                                   hate (haine, la)  1995
# 99        101                                      bottle rocket  1996
# 110       112                                rumble in the bronx  1995
# 113       115                          happiness is in the field  1995
# 118       120                                       race the sun  1996
# 119       121                           boys of st. vincent, the  1993
# 122       124            star maker, the (uomo delle stelle, l')  1995
# 125       127        silence of the palace, the (saimt el qusur)  1994
# 127       129                                     pie in the sky  1995
# 131       133                                          nueba yol  1995
# 134       136                   from the journals of jean seberg  1995
# 135       137                                    man of the year  1995
# 138       140                              up close and personal  1996
# 151       153                                     batman forever  1995
# 152       154                                      belle de jour  1967
# 154       156                                   blue in the face  1995
# 162       164                              devil in a blue dress  1995
# 163       165                         die hard: with a vengeance  1995
# 167       169                   free willy 2: the adventure home  1995
# 176       178                               love & human remains  1993
# 179       181            mighty morphin power rangers: the movie  1995
# 197       199  umbrellas of cherbourg, the (parapluies de che...  1964
#
#                                         stripped_title  \
# 4                          father of the bride part ii
# 23                                              powder
# 27                                          persuasion
# 31                                      twelve monkeys
# 35                                    dead man walking
# 36                              across the sea of time
# 45                       how to make an american quilt
# 50                                      guardian angel
# 55                             kids of the round table
# 56                               home for the holidays
# 57                              postino il the postman
# 60                                      eye for an eye
# 62   dont be a menace to south central while drinki...
# 65                    lawnmower man  beyond cyberspace
# 72                                          misérables
# 82               once upon a time when we were colored
# 83                         last summer in the hamptons
# 94                              in the bleak midwinter
# 95                                          hate haine
# 99                                       bottle rocket
# 110                                rumble in the bronx
# 113                          happiness is in the field
# 118                                       race the sun
# 119                                 boys of st vincent
# 122                   star maker the uomo delle stelle
# 125                              silence of the palace
# 127                                     pie in the sky
# 131                                          nueba yol
# 134                   from the journals of jean seberg
# 135                                    man of the year
# 138                              up close and personal
# 151                                     batman forever
# 152                                      belle de jour
# 154                                   blue in the face
# 162                              devil in a blue dress
# 163                          die hard with a vengeance
# 167                     free willy  the adventure home
# 176                                love  human remains
# 179             mighty morphin power rangers the movie
# 197  umbrellas of cherbourg the parapluies de cherb...
#
#                                           no_secondary  \
# 4                          father of the bride part ii
# 23                                              powder
# 27                                          persuasion
# 31                                      twelve monkeys
# 35                                    dead man walking
# 36                              across the sea of time
# 45                       how to make an american quilt
# 50                                      guardian angel
# 55                             kids of the round table
# 56                               home for the holidays
# 57                                         postino, il
# 60                                      eye for an eye
# 62   don't be a menace to south central while drink...
# 65                  lawnmower man 2: beyond cyberspace
# 72                                          misérables
# 82            once upon a time... when we were colored
# 83                         last summer in the hamptons
# 94                              in the bleak midwinter
# 95                                         hate (haine
# 99                                       bottle rocket
# 110                                rumble in the bronx
# 113                          happiness is in the field
# 118                                       race the sun
# 119                                boys of st. vincent
# 122                 star maker, the (uomo delle stelle
# 125                              silence of the palace
# 127                                     pie in the sky
# 131                                          nueba yol
# 134                   from the journals of jean seberg
# 135                                    man of the year
# 138                              up close and personal
# 151                                     batman forever
# 152                                      belle de jour
# 154                                   blue in the face
# 162                              devil in a blue dress
# 163                         die hard: with a vengeance
# 167                   free willy 2: the adventure home
# 176                               love & human remains
# 179            mighty morphin power rangers: the movie
# 197  umbrellas of cherbourg, the (parapluies de che...
#
#                                         only_secondary  year+1  year-1
# 4                          father of the bride part ii    1996    1994
# 23                                              powder    1996    1994
# 27                                          persuasion    1996    1994
# 31                                      twelve monkeys    1996    1994
# 35                                    dead man walking    1996    1994
# 36                              across the sea of time    1996    1994
# 45                       how to make an american quilt    1996    1994
# 50                                      guardian angel    1995    1993
# 55                             kids of the round table    1996    1994
# 56                               home for the holidays    1996    1994
# 57                                         the postman    1995    1993
# 60                                      eye for an eye    1997    1995
# 62   don't be a menace to south central while drink...    1997    1995
# 65                  lawnmower man 2: beyond cyberspace    1997    1995
# 72                                          misérables    1996    1994
# 82            once upon a time... when we were colored    1996    1994
# 83                         last summer in the hamptons    1996    1994
# 94                              in the bleak midwinter    1996    1994
# 95                                         hate (haine    1996    1994
# 99                                       bottle rocket    1997    1995
# 110                                rumble in the bronx    1996    1994
# 113                          happiness is in the field    1996    1994
# 118                                       race the sun    1997    1995
# 119                                boys of st. vincent    1994    1992
# 122                 star maker, the (uomo delle stelle    1996    1994
# 125                              silence of the palace    1995    1993
# 127                                     pie in the sky    1996    1994
# 131                                          nueba yol    1996    1994
# 134                   from the journals of jean seberg    1996    1994
# 135                                    man of the year    1996    1994
# 138                              up close and personal    1997    1995
# 151                                     batman forever    1996    1994
# 152                                      belle de jour    1968    1966
# 154                                   blue in the face    1996    1994
# 162                              devil in a blue dress    1996    1994
# 163                         die hard: with a vengeance    1996    1994
# 167                   free willy 2: the adventure home    1996    1994
# 176                               love & human remains    1994    1992
# 179            mighty morphin power rangers: the movie    1996    1994
# 197  umbrellas of cherbourg, the (parapluies de che...    1965    1963

# %%
imdb_to_match[imdb_to_match['stripped_title'] == 'umbrellas of cherbourg']
# Out:
#           tconst                       title  year          stripped_title  \
# 36173  tt0058450  the umbrellas of cherbourg  1964  umbrellas of cherbourg
#
#                  no_secondary          only_secondary
# 36173  umbrellas of cherbourg  umbrellas of cherbourg

# %%
unmatched_new = unmatched.copy(deep=True)

def remove_articles(title): 
    articles = {' the ', ' a ', ' an ', ' le ', ' la ', ' l\' ', ' el ', ' dir', ' der'}
    new_title = ''.join(title)
    for article in articles: 
        if (article in new_title): 
            new_title = new_title[:new_title.index(article)-1]
    return new_title 

unmatched_new['stripped_title'] = unmatched_new['stripped_title'].apply(lambda x: remove_articles(x))

# %% [markdown]
# # Final attempt

# %%
movies_full = movies_full.astype({'title':'string'})
imdb_full = imdb_full.replace('\\N', None)
imdb_full = imdb_full.astype({'title':'string', 
                              'originalTitle': 'string',
                              'year':'int64'})

# %%
movies_full.shape
# Out:
# (3883, 4)

# %%
ml_unmatched = movies_full.copy(deep='True')
ml_unmatched = ml_unmatched.drop(columns = ['genres'])

imdb = imdb_full.copy(deep='True')
imdb = imdb.drop(columns = ['averageRating','numVotes','titleType','isAdult','runtimeMinutes', 'imdb_genres'])

unmatched_movie_ids = ml_unmatched['movie_id']

# %%
# match on title + year 
match = pd.merge(ml_unmatched, imdb, on=['title', 'year'])
matched_df_full = match.copy(deep='True')

matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

print("new matches: " + str(match.shape))
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))
# Out:
# new matches: (2455, 5)
# all matches: (2455, 5)
# left to match: (1460, 3)

# %%
# match on original title + year 
imdb['originalTitle'] = imdb['originalTitle'].apply(lambda x: x.lower())

match = pd.merge(ml_unmatched, imdb, 
                 left_on=['title', 'year'],
                 right_on=['originalTitle', 'year'])

matched_df_full = matched_df_full.append(match, ignore_index=True)

matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

print("new matches: " + str(match.shape))
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))
# Out:
# new matches: (36, 6)
# all matches: (2491, 7)
# left to match: (1424, 3)

# %%
# match on original title + (year + 1)
ml_unmatched['year+1'] = ml_unmatched['year'] + 1
ml_unmatched['year-1'] = ml_unmatched['year'] - 1


match = pd.merge(ml_unmatched, imdb, 
                 left_on=['title', 'year+1'],
                 right_on=['originalTitle', 'year'])

matched_df_full = matched_df_full.append(match, ignore_index=True)

matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

print("new matches: " + str(match.shape))
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))

# match on title + (year+1)

ml_unmatched['year+1'] = ml_unmatched['year'] + 1
ml_unmatched['year-1'] = ml_unmatched['year'] - 1


match = pd.merge(ml_unmatched, imdb, 
                 left_on=['title', 'year+1'],
                 right_on=['title', 'year'])

matched_df_full = matched_df_full.append(match, ignore_index=True)

matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

print("new matches: " + str(match.shape))
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))
# Out:
# new matches: (65, 9)
# all matches: (2556, 11)
# left to match: (1361, 5)
# new matches: (1, 8)
# all matches: (2557, 11)
# left to match: (1360, 5)

# %%
# match on a year that is 1 off 
# match on original title 
match = pd.merge(ml_unmatched, imdb, 
                 left_on=['title', 'year-1'],
                 right_on=['originalTitle', 'year'])

matched_df_full = matched_df_full.append(match, ignore_index=True)

matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

print("new matches: " + str(match.shape))
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))

# match on a year that is 1 off 
# match on title 
match = pd.merge(ml_unmatched, imdb, 
                 left_on=['title', 'year-1'],
                 right_on=['title', 'year'])

matched_df_full = matched_df_full.append(match, ignore_index=True)

matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

print("new matches: " + str(match.shape))
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))
# Out:
# new matches: (82, 9)
# all matches: (2639, 11)
# left to match: (1278, 5)
# new matches: (8, 8)
# all matches: (2647, 11)
# left to match: (1270, 5)

# %%
# reset df 
ml_unmatched = ml_unmatched.drop(columns=['year+1', 'year-1'])

# %%
import string 
from string import punctuation

def reposition_movielens_article(title): 
    articles = {', the', ', a', ', an', ', le', ', la', ', l\'', ', el', ', dir', ', der'}
    for article in articles: 
        if(title[-len(article):] == article):
            title = article[2:] + ' ' + title[:title.index(article)]
    return title 

def remove_movielens_articles(title):
    new_title = title
    articles = {', the', ', a', ', an', ', le', ', la', ', l\'', ', el', ', dir', ', der'}
    for article in articles: 
        if article in title: 
            new_title = title[:title.index(article)]
    return new_title 

def remove_imdb_articles(title): 
    new_title = title
    articles = {'the ', 'a ', 'an ', 'le ', 'la ', 'l\' ', 'el ', 'dir', 'der'}
    for article in articles: 
        if article in title: 
            new_title = title[title.index(article) + len(article):] 
    return new_title

def remove_punctuation(title): 
    new_title = title
    if (any(p in title for p in punctuation)):
        new_title = title.translate(str.maketrans('', '', string.punctuation))
    return new_title 

def remove_numbers(title):
    no_digits = []
    for i in title:
        if not i.isdigit():
            no_digits.append(i)
    return ''.join(no_digits)

def remove_secondary(title):
    new_title = title
    if ('(' in title and ')' in title):
        new_title = title[: title.index('(')-1]
    
    return new_title 

def extract_secondary(title):
    new_title = title
    if ('(' in title and ')' in title):
        new_title = title[title.index('(') + 1: title.index(')')]
    return new_title

# %%
# fix the article notation movielens has
# The notation is i.e. Contender, The 

ml_unmatched_articles = ml_unmatched.copy(deep='True')

ml_unmatched_articles['title'] = ml_unmatched_articles['title'].apply(lambda x: reposition_movielens_articles_from_end(x))

match = pd.merge(ml_unmatched_articles, imdb, 
                 left_on=['title', 'year'],
                 right_on=['originalTitle', 'year'])

matched_df_full = matched_df_full.append(match, ignore_index=True)

matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

print("new matches: " + str(match.shape))
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))

ml_unmatched_articles = ml_unmatched_articles[ml_unmatched_articles['movie_id'].isin(unmatched_movie_ids)]

# article notation change but match with title instead of originalTitle 

match = pd.merge(ml_unmatched_articles, imdb, 
                 left_on=['title', 'year'],
                 right_on=['title', 'year'])

matched_df_full = matched_df_full.append(match, ignore_index=True)


matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

print("new matches: " + str(match.shape))
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))
# Out:
# new matches: (715, 6)
# all matches: (3362, 11)
# left to match: (560, 3)
# new matches: (19, 5)
# all matches: (3381, 11)
# left to match: (541, 3)

# %%
# let's try the +- year again 

ml_unmatched_articles = ml_unmatched_articles[ml_unmatched_articles['movie_id'].isin(unmatched_movie_ids)]

ml_unmatched_articles['year+1'] = ml_unmatched_articles['year']+1
ml_unmatched_articles['year-1'] = ml_unmatched_articles['year']-1

match = pd.merge(ml_unmatched_articles, imdb, 
                 left_on=['title', 'year+1'],
                 right_on=['originalTitle', 'year'])

matched_df_full = matched_df_full.append(match, ignore_index=True)

matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

print("new matches: " + str(match.shape))
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))

ml_unmatched_articles = ml_unmatched_articles[ml_unmatched_articles['movie_id'].isin(unmatched_movie_ids)]

# article notation change but match with title instead of originalTitle 

match = pd.merge(ml_unmatched_articles, imdb, 
                 left_on=['title', 'year+1'],
                 right_on=['title', 'year'])

matched_df_full = matched_df_full.append(match, ignore_index=True)

matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

print("new matches: " + str(match.shape))
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))
# Out:
# new matches: (17, 9)
# all matches: (3398, 11)
# left to match: (525, 3)
# new matches: (1, 8)
# all matches: (3399, 11)
# left to match: (524, 3)

# %%
# let's try the +- year again 

ml_unmatched_articles = ml_unmatched_articles[ml_unmatched_articles['movie_id'].isin(unmatched_movie_ids)]

ml_unmatched_articles['year+1'] = ml_unmatched_articles['year']+1
ml_unmatched_articles['year-1'] = ml_unmatched_articles['year']-1

match = pd.merge(ml_unmatched_articles, imdb, 
                 left_on=['title', 'year-1'],
                 right_on=['originalTitle', 'year'])

matched_df_full = matched_df_full.append(match, ignore_index=True)

matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

print("new matches: " + str(match.shape))
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))

ml_unmatched_articles = ml_unmatched_articles[ml_unmatched_articles['movie_id'].isin(unmatched_movie_ids)]

# article notation change but match with title instead of originalTitle 

match = pd.merge(ml_unmatched_articles, imdb, 
                 left_on=['title', 'year-1'],
                 right_on=['title', 'year'])

matched_df_full = matched_df_full.append(match, ignore_index=True)

matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

print("new matches: " + str(match.shape))
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))
# Out:
# new matches: (20, 9)
# all matches: (3419, 11)
# left to match: (504, 3)
# new matches: (1, 8)
# all matches: (3420, 11)
# left to match: (503, 3)

# %%
# no numbers + year

ml_unmatched_numbers = ml_unmatched.copy(deep='True')
ml_unmatched_numbers['year+1'] = ml_unmatched_numbers['year']+1
ml_unmatched_numbers['year+1'] = ml_unmatched_numbers['year']+1

imdb_numbers = imdb.copy(deep='True')

ml_unmatched_numbers['title'] = ml_unmatched_numbers['title'].apply(lambda x: remove_punctuation(x))
imdb_numbers['title'] = imdb_numbers['title'].apply(lambda x: remove_punctuation(x))

match = pd.merge(ml_unmatched_numbers, imdb_numbers, 
                 left_on=['title', 'year'],
                 right_on=['title', 'year'])

matched_df_full = matched_df_full.append(match, ignore_index=True)

matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

print("new matches: " + str(match.shape))
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))

# no punctuation + (year+1)

ml_unmatched_numbers = ml_unmatched.copy(deep='True')
ml_unmatched_numbers['year+1'] = ml_unmatched_numbers['year']+1

imdb_numbers = imdb.copy(deep='True')

ml_unmatched_numbers['title'] = ml_unmatched_numbers['title'].apply(lambda x: remove_punctuation(x))
imdb_numbers['title'] = imdb_numbers['title'].apply(lambda x: remove_punctuation(x))

match = pd.merge(ml_unmatched_numbers, imdb_numbers, 
                 left_on=['title', 'year+1'],
                 right_on=['title', 'year'])

matched_df_full = matched_df_full.append(match, ignore_index=True)

matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

print("new matches: " + str(match.shape))
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))

# no punctuation + (year-1)

ml_unmatched_numbers = ml_unmatched.copy(deep='True')
ml_unmatched_numbers['year-1'] = ml_unmatched_numbers['year']-1

imdb_numbers = imdb.copy(deep='True')

ml_unmatched_numbers['title'] = ml_unmatched_numbers['title'].apply(lambda x: remove_punctuation(x))
imdb_numbers['title'] = imdb_numbers['title'].apply(lambda x: remove_punctuation(x))

match = pd.merge(ml_unmatched_numbers, imdb_numbers, 
                 left_on=['title', 'year-1'],
                 right_on=['title', 'year'])

matched_df_full = matched_df_full.append(match, ignore_index=True)

matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

print("new matches: " + str(match.shape))
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))
# Out:
# new matches: (0, 6)
# all matches: (3455, 11)
# left to match: (471, 3)
# new matches: (0, 7)
# all matches: (3455, 11)
# left to match: (471, 3)
# new matches: (0, 7)
# all matches: (3455, 11)
# left to match: (471, 3)

# %%
# no punctuation + year

ml_unmatched_punctuation = ml_unmatched.copy(deep='True')
ml_unmatched_punctuation['year+1'] = ml_unmatched_punctuation['year']+1
ml_unmatched_punctuation['year+1'] = ml_unmatched_punctuation['year']+1

imdb_punctuation = imdb.copy(deep='True')

ml_unmatched_punctuation['title'] = ml_unmatched_punctuation['title'].apply(lambda x: remove_punctuation(x))
imdb_punctuation['title'] = imdb_punctuation['title'].apply(lambda x: remove_punctuation(x))

match = pd.merge(ml_unmatched_punctuation, imdb_punctuation, 
                 left_on=['title', 'year'],
                 right_on=['title', 'year'])

matched_df_full = matched_df_full.append(match, ignore_index=True)

matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

print("new matches: " + str(match.shape))
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))

# no punctuation + (year+1)

ml_unmatched_punctuation = ml_unmatched.copy(deep='True')
ml_unmatched_punctuation['year+1'] = ml_unmatched_punctuation['year']+1

imdb_punctuation = imdb.copy(deep='True')

ml_unmatched_punctuation['title'] = ml_unmatched_punctuation['title'].apply(lambda x: remove_punctuation(x))
imdb_punctuation['title'] = imdb_punctuation['title'].apply(lambda x: remove_punctuation(x))

match = pd.merge(ml_unmatched_punctuation, imdb_punctuation, 
                 left_on=['title', 'year+1'],
                 right_on=['title', 'year'])

matched_df_full = matched_df_full.append(match, ignore_index=True)

matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

print("new matches: " + str(match.shape))
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))

# no punctuation + (year-1)

ml_unmatched_punctuation = ml_unmatched.copy(deep='True')
ml_unmatched_punctuation['year-1'] = ml_unmatched_punctuation['year']-1

imdb_punctuation = imdb.copy(deep='True')

ml_unmatched_punctuation['title'] = ml_unmatched_punctuation['title'].apply(lambda x: remove_punctuation(x))
imdb_punctuation['title'] = imdb_punctuation['title'].apply(lambda x: remove_punctuation(x))

match = pd.merge(ml_unmatched_punctuation, imdb_punctuation, 
                 left_on=['title', 'year-1'],
                 right_on=['title', 'year'])

matched_df_full = matched_df_full.append(match, ignore_index=True)

matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

print("new matches: " + str(match.shape))
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))
# Out:
# new matches: (0, 6)
# all matches: (3454, 11)
# left to match: (472, 3)
# new matches: (0, 7)
# all matches: (3454, 11)
# left to match: (472, 3)
# new matches: (1, 7)
# all matches: (3455, 11)
# left to match: (471, 3)

# %%
# secondary title

ml_secondary_title = ml_unmatched.copy(deep='True')
ml_secondary_title['year+1'] = ml_unmatched_punctuation['year']+1
ml_secondary_title['year+1'] = ml_unmatched_punctuation['year']+1


ml_secondary_title['title'] = ml_secondary_title['title'].apply(lambda x: extract_secondary(x))

match = pd.merge(ml_secondary_title, imdb, 
                 left_on=['title', 'year'],
                 right_on=['title', 'year'])

matched_df_full = matched_df_full.append(match, ignore_index=True)

matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

print("new matches: " + str(match.shape))
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))

# no punctuation + (year+1)

ml_secondary_title = ml_unmatched.copy(deep='True')
ml_secondary_title['year+1'] = ml_secondary_title['year']+1


ml_secondary_title['title'] = ml_secondary_title['title'].apply(lambda x: extract_secondary(x))

match = pd.merge(ml_secondary_title, imdb_punctuation, 
                 left_on=['title', 'year+1'],
                 right_on=['title', 'year'])

matched_df_full = matched_df_full.append(match, ignore_index=True)

matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

print("new matches: " + str(match.shape))
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))

# no punctuation + (year-1)

ml_secondary_title = ml_unmatched.copy(deep='True')
ml_secondary_title['year-1'] = ml_secondary_title['year']-1


ml_secondary_title['title'] = ml_secondary_title['title'].apply(lambda x: extract_secondary(x))

match = pd.merge(ml_unmatched_punctuation, imdb_punctuation, 
                 left_on=['title', 'year-1'],
                 right_on=['title', 'year'])

matched_df_full = matched_df_full.append(match, ignore_index=True)

matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

print("new matches: " + str(match.shape))
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))
# Out:
# new matches: (20, 6)
# all matches: (3475, 11)
# left to match: (451, 3)
# new matches: (1, 7)
# all matches: (3476, 11)
# left to match: (450, 3)
# new matches: (1, 7)
# all matches: (3477, 11)
# left to match: (450, 3)

# %%
# secondary title

ml_secondary_title = ml_unmatched.copy(deep='True')
ml_secondary_title['year+1'] = ml_unmatched_punctuation['year']+1
ml_secondary_title['year+1'] = ml_unmatched_punctuation['year']+1


ml_secondary_title['title'] = ml_secondary_title['title'].apply(lambda x: remove_secondary(x))

match = pd.merge(ml_secondary_title, imdb, 
                 left_on=['title', 'year'],
                 right_on=['title', 'year'])

matched_df_full = matched_df_full.append(match, ignore_index=True)

matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

print("new matches: " + str(match.shape))
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))

# no punctuation + (year+1)

ml_secondary_title = ml_unmatched.copy(deep='True')
ml_secondary_title['year+1'] = ml_secondary_title['year']+1


ml_secondary_title['title'] = ml_secondary_title['title'].apply(lambda x: remove_secondary(x))

match = pd.merge(ml_secondary_title, imdb_punctuation, 
                 left_on=['title', 'year+1'],
                 right_on=['title', 'year'])

matched_df_full = matched_df_full.append(match, ignore_index=True)

matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

print("new matches: " + str(match.shape))
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))

# no punctuation + (year-1)

ml_secondary_title = ml_unmatched.copy(deep='True')
ml_secondary_title['year-1'] = ml_secondary_title['year']-1


ml_secondary_title['title'] = ml_secondary_title['title'].apply(lambda x: remove_secondary(x))

match = pd.merge(ml_unmatched_punctuation, imdb_punctuation, 
                 left_on=['title', 'year-1'],
                 right_on=['title', 'year'])

matched_df_full = matched_df_full.append(match, ignore_index=True)

matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

print("new matches: " + str(match.shape))
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))
# Out:
# new matches: (109, 6)
# all matches: (3586, 11)
# left to match: (341, 3)
# new matches: (9, 7)
# all matches: (3595, 11)
# left to match: (332, 3)
# new matches: (1, 7)
# all matches: (3596, 11)
# left to match: (332, 3)

# %%
# secondary title + article reposition

ml_secondary_title = ml_unmatched.copy(deep='True')
ml_secondary_title['year+1'] = ml_unmatched_punctuation['year']+1
ml_secondary_title['year+1'] = ml_unmatched_punctuation['year']+1


ml_secondary_title['title'] = ml_secondary_title['title'].apply(lambda x: remove_secondary(x))
ml_secondary_title['title'] = ml_secondary_title['title'].apply(lambda x: reposition_movielens_article(x))


match = pd.merge(ml_secondary_title, imdb, 
                 left_on=['title', 'year'],
                 right_on=['title', 'year'])

matched_df_full = matched_df_full.append(match, ignore_index=True)

matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

print("new matches: " + str(match.shape))
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))

# no punctuation + (year+1)

ml_secondary_title = ml_unmatched.copy(deep='True')
ml_secondary_title['year+1'] = ml_secondary_title['year']+1


ml_secondary_title['title'] = ml_secondary_title['title'].apply(lambda x: remove_secondary(x))
ml_secondary_title['title'] = ml_secondary_title['title'].apply(lambda x: reposition_movielens_article(x))

match = pd.merge(ml_secondary_title, imdb_punctuation, 
                 left_on=['title', 'year+1'],
                 right_on=['title', 'year'])

matched_df_full = matched_df_full.append(match, ignore_index=True)

matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

print("new matches: " + str(match.shape))
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))

# no punctuation + (year-1)

ml_secondary_title = ml_unmatched.copy(deep='True')
ml_secondary_title['year-1'] = ml_secondary_title['year']-1


ml_secondary_title['title'] = ml_secondary_title['title'].apply(lambda x: remove_secondary(x))
ml_secondary_title['title'] = ml_secondary_title['title'].apply(lambda x: reposition_movielens_article(x))

match = pd.merge(ml_unmatched_punctuation, imdb_punctuation, 
                 left_on=['title', 'year-1'],
                 right_on=['title', 'year'])

matched_df_full = matched_df_full.append(match, ignore_index=True)

matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

print("new matches: " + str(match.shape))
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))
# Out:
# new matches: (60, 6)
# all matches: (3656, 11)
# left to match: (274, 3)
# new matches: (4, 7)
# all matches: (3660, 11)
# left to match: (270, 3)
# new matches: (1, 7)
# all matches: (3661, 11)
# left to match: (270, 3)

# %%
# replace & with and 

def replace_ampersand(title): 
    if ('&' in title): 
        title = title.replace('&', 'and')
# secondary title + article reposition

ml_secondary_title = ml_unmatched.copy(deep='True')

ml_secondary_title['title'] = ml_secondary_title['title'].apply(lambda x: replace_ampersand(x))

match = pd.merge(ml_secondary_title, imdb, 
                 left_on=['title', 'year'],
                 right_on=['title', 'year'])

matched_df_full = matched_df_full.append(match, ignore_index=True)

matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

print("new matches: " + str(match.shape))
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))

# no punctuation + (year+1)

ml_secondary_title = ml_unmatched.copy(deep='True')
ml_secondary_title['year+1'] = ml_secondary_title['year']+1

ml_secondary_title['title'] = ml_secondary_title['title'].apply(lambda x: replace_ampersand(x))

match = pd.merge(ml_secondary_title, imdb_punctuation, 
                 left_on=['title', 'year+1'],
                 right_on=['title', 'year'])

matched_df_full = matched_df_full.append(match, ignore_index=True)

matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

print("new matches: " + str(match.shape))
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))

# no punctuation + (year-1)

ml_secondary_title = ml_unmatched.copy(deep='True')
ml_secondary_title['year-1'] = ml_secondary_title['year']-1

ml_secondary_title['title'] = ml_secondary_title['title'].apply(lambda x: replace_ampersand(x))

match = pd.merge(ml_unmatched_punctuation, imdb_punctuation, 
                 left_on=['title', 'year-1'],
                 right_on=['title', 'year'])

matched_df_full = matched_df_full.append(match, ignore_index=True)

matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

print("new matches: " + str(match.shape))
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))
# Out:
# new matches: (0, 5)
# all matches: (3662, 11)
# left to match: (270, 3)
# new matches: (0, 7)
# all matches: (3662, 11)
# left to match: (270, 3)
# new matches: (1, 7)
# all matches: (3663, 11)
# left to match: (270, 3)

# %%
# remvove article from movielens 
# i don't think this works
def replace_ampersand(title): 
    if ('&' in title): 
        print(title)
        title = title.replace('&', 'and')
    return title
# secondary title + article reposition

ml_secondary_title = ml_unmatched.copy(deep='True')

ml_secondary_title['title'] = ml_secondary_title['title'].apply(lambda x: remove_movielens_articles(x))

match = pd.merge(ml_secondary_title, imdb, 
                 left_on=['title', 'year'],
                 right_on=['title', 'year'])

matched_df_full = matched_df_full.append(match, ignore_index=True)

matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

print("new matches: " + str(match.shape))
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))

# no punctuation + (year+1)

ml_secondary_title = ml_unmatched.copy(deep='True')
ml_secondary_title['year+1'] = ml_secondary_title['year']+1

ml_secondary_title['title'] = ml_secondary_title['title'].apply(lambda x: remove_movielens_articles(x))

match = pd.merge(ml_secondary_title, imdb_punctuation, 
                 left_on=['title', 'year+1'],
                 right_on=['title', 'year'])

matched_df_full = matched_df_full.append(match, ignore_index=True)

matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

print("new matches: " + str(match.shape))
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))

# no punctuation + (year-1)

ml_secondary_title = ml_unmatched.copy(deep='True')
ml_secondary_title['year-1'] = ml_secondary_title['year']-1

ml_secondary_title['title'] = ml_secondary_title['title'].apply(lambda x: remove_movielens_articles(x))

match = pd.merge(ml_unmatched_punctuation, imdb_punctuation, 
                 left_on=['title', 'year-1'],
                 right_on=['title', 'year'])

matched_df_full = matched_df_full.append(match, ignore_index=True)

matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

print("new matches: " + str(match.shape))
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))
# Out:
# new matches: (0, 5)
# all matches: (3683, 11)
# left to match: (252, 3)
# new matches: (0, 7)
# all matches: (3683, 11)
# left to match: (252, 3)
# new matches: (1, 7)
# all matches: (3684, 11)
# left to match: (252, 3)

# %%
replace_ampersand('dumb & dumber')
# Out:
# 'dumb and dumber'

# %%
ml_unmatched.tail(50)
# Out:
#       movie_id                                              title  year
# 3394      3463                                        last resort  1994
# 3395      3464                                       solar crisis  1993
# 3403      3472         horror hotel (a.k.a. the city of the dead)  1960
# 3453      3522              sacco and vanzetti (sacco e vanzetti)  1971
# 3463      3532                freedom for us (à nous la liberté )  1931
# 3485      3554                                love and basketball  2000
# 3491      3560                         phantom love (ai no borei)  1978
# 3499      3568                      smiling fish and goat on fire  1999
# 3502      3571                                          time code  2000
# 3508      3577                                   two moon juction  1988
# 3523      3592                time masters (les maîtres du temps)  1982
# 3533      3602                                        g. i. blues  1960
# 3543      3612                          slipper and the rose, the  1976
# 3554      3623                              mission: impossible 2  2000
# 3557      3626                                        8 1/2 women  1999
# 3572      3641                                  woman of paris, a  1923
# 3576      3645                   cleo from 5 to 7 (cléo de 5 à 7)  1962
# 3590      3659                                      quatermass ii  1957
# 3591      3660                                      puppet master  1989
# 3592      3661                                   puppet master ii  1990
# 3593      3662                puppet master iii: toulon's revenge  1991
# 3594      3663                                    puppet master 4  1993
# 3595      3664                 puppet master 5: the final chapter  1994
# 3596      3665                         curse of the puppet master  1998
# 3597      3666                                 retro puppetmaster  1999
# 3625      3694                        toxic avenger, part ii, the  1989
# 3634      3703                mad max 2 (a.k.a. the road warrior)  1981
# 3653      3722                                        live virgin  1999
# 3667      3736                                  big carnival, the  1951
# 3680      3749                  time regained (le temps retrouvé)  1999
# 3683      3752                               me, myself and irene  2000
# 3685      3754            adventures of rocky and bullwinkle, the  2000
# 3693      3762                            daughter of dr. jeckyll  1957
# 3695      3764                                              f/x 2  1992
# 3727      3796     wisdom of crocodiles, the (a.k.a. immortality)  2000
# 3739      3808                            two women (la ciociara)  1961
# 3743      3812     everything you always wanted to know about sex  1972
# 3775      3845  and god created woman (et dieu&#8230;créa la f...  1956
# 3780      3850                   whatever happened to aunt alice?  1969
# 3781      3851                            i'm the one that i want  2000
# 3786      3856                                       autumn heart  1999
# 3794      3864            godzilla 2000 (gojira ni-sen mireniamu)  1999
# 3799      3869            naked gun 2 1/2: the smell of fear, the  1991
# 3806      3876                                        jerry & tom  1998
# 3820      3890                                         back stage  2000
# 3830      3900                   crime and punishment in suburbia  2000
# 3834      3904                                uninvited guest, an  2000
# 3844      3914                            broken hearts club, the  2000
# 3850      3920       faraway, so close (in weiter ferne, so nah!)  1993
# 3865      3935                                             kronos  1973

# %%
imdb[imdb['title'] == 'les miserables']
# Out:
#           tconst           title   originalTitle  year
# 25325  tt0044907  les miserables  les miserables  1952
# 51163  tt0077936  les miserables  les miserables  1978

# %%
imdb[imdb['title'] == 'la haine']
# Out:
#            tconst     title originalTitle  year
# 76275   tt0113247  la haine      la haine  1995
# 192196  tt0448513  la haine      la haine  1910

# %%
imdb[imdb['title'] == 'das versprechen']
# Out:
#           tconst            title    originalTitle  year
# 75339  tt0111613  das versprechen  das versprechen  1994

# %%
# puppet master ii
imdb[imdb['title'] == 'the puppet master ii']
# Out:
# Empty DataFrame
# Columns: [tconst, title, originalTitle, year]
# Index: []

# %%
manually_fixing_df = pd.read_csv('https://raw.githubusercontent.com/jennyzhang0215/MovieLens-IMDB/master/movielens/statistics/manually_fixed_title_name', delimiter='|')

# %%
manually_fixing_df.head(20)
# Out:
#                                      wrong_title_name  \
# 0    to wong foo, thanks for everything! julie newmar
# 1                        faster pussycat! kill! kill!
# 2                        star trek: the wrath of khan
# 3                                       jungle2jungle
# 4                                  when the cats away
# 5                                          mrs. brown
# 6         tales from the crypt presents: demon knight
# 7    tales from the crypt presents: bordello of blood
# 8                          jackie chan's first strike
# 9                          die hard: with a vengeance
# 10  the englishman who went up a hill, but came do...
# 11                     daniel defoe's robinson crusoe
# 12           davy crockett, king of the wild frontier
# 13            the cook the thief his wife & her lover
# 14              rosencrantz and guildenstern are dead
# 15           thirty-two short films about glenn gould
# 16                        the garden of finzi-contini
# 17                                    oscar & lucinda
# 18                                     u.s. marshalls
# 19                               die xue shuang xiong
#
#                                    correct_title_name
# 0     to wong foo thanks for everything, julie newmar
# 1                       faster, pussycat! kill! kill!
# 2                     star trek ii: the wrath of khan
# 3                                     jungle 2 jungle
# 4                                 when the cat's away
# 5                                           mrs brown
# 6                  tales from the crypt: demon knight
# 7                                   bordello of blood
# 8                        police story 4: first strike
# 9                           die hard with a vengeance
# 10  the englishman who went up a hill but came dow...
# 11                                    robinson crusoe
# 12           davy crockett: king of the wild frontier
# 13          the cook, the thief, his wife & her lover
# 14                rosencrantz & guildenstern are dead
# 15           thirty two short films about glenn gould
# 16                   the garden of the finzi-continis
# 17                                  oscar and lucinda
# 18                                      u.s. marshals
# 19                                         the killer

# %%
# remvove article from movielens 
# i don't think this works
def replace_manually(title): 
    fixed_title = title
    if (len(manually_fixing_df[manually_fixing_df['wrong_title_name'] == title] == 1)): 
        fixed_title = manually_fixing_df[manually_fixing_df['wrong_title_name'] == title]['correct_title_name'].values[0]
    return fixed_title

# secondary title + article reposition

ml_secondary_title = ml_unmatched.copy(deep='True')

ml_secondary_title['title'] = ml_secondary_title['title'].apply(lambda x: replace_manually(x))

match = pd.merge(ml_secondary_title, imdb, 
                 left_on=['title', 'year'],
                 right_on=['title', 'year'])

matched_df_full = matched_df_full.append(match, ignore_index=True)

matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

print("new matches: " + str(match.shape))
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))

# no punctuation + (year+1)

ml_secondary_title = ml_unmatched.copy(deep='True')
ml_secondary_title['year+1'] = ml_secondary_title['year']+1

ml_secondary_title['title'] = ml_secondary_title['title'].apply(lambda x: remove_movielens_articles(x))

match = pd.merge(ml_secondary_title, imdb_punctuation, 
                 left_on=['title', 'year+1'],
                 right_on=['title', 'year'])

matched_df_full = matched_df_full.append(match, ignore_index=True)

matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

print("new matches: " + str(match.shape))
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))

# no punctuation + (year-1)

ml_secondary_title = ml_unmatched.copy(deep='True')
ml_secondary_title['year-1'] = ml_secondary_title['year']-1

ml_secondary_title['title'] = ml_secondary_title['title'].apply(lambda x: remove_movielens_articles(x))

match = pd.merge(ml_unmatched_punctuation, imdb_punctuation, 
                 left_on=['title', 'year-1'],
                 right_on=['title', 'year'])

matched_df_full = matched_df_full.append(match, ignore_index=True)

matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

print("new matches: " + str(match.shape))
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))
# Out:
# new matches: (50, 5)
# all matches: (3734, 11)
# left to match: (202, 3)
# new matches: (0, 7)
# all matches: (3734, 11)
# left to match: (202, 3)
# new matches: (1, 7)
# all matches: (3735, 11)
# left to match: (202, 3)

# %%
ml_unmatched.tail()
# Out:
#       movie_id                                         title  year
# 3830      3900              crime and punishment in suburbia  2000
# 3834      3904                           uninvited guest, an  2000
# 3844      3914                       broken hearts club, the  2000
# 3850      3920  faraway, so close (in weiter ferne, so nah!)  1993
# 3865      3935                                        kronos  1973

# %%
# I will run through the unmatched rows and see if there are higher year mismatches for any of them 
count = 0;
for index, row in ml_unmatched.iterrows():
    title = row['title']
    ml_year = row['year'] 
    
    find_in_imdb = imdb[imdb['title'] == title]
    if (len(find_in_imdb) >= 1): 
        print("__________________________________")
        print(title + " ML year: " + str(ml_year))
        print("Found match in imdb. ")
        print(find_in_imdb)
        count = count+1; 
        
print("total " + str(count))

# %%
manual_matching_dict = {'dream man': 'tt0101770', 
               'new york cop': 'tt0368893',
               'true crime': 'tt0139668',
               'costa brava': 'tt0109489',
               'victor/victoria': 'tt0265987',
               'drunks': 'tt0112907',
               'farmer & chase': 'tt0113031',
               'kids of survival': 'tt0107314',
               'blood & wine': 'tt0859643',
               'hearts and minds': 'tt0071604',
               'alien escape': 'tt0112318',
               'other voices, other rooms': 'tt0119845',
               'time tracers': 'tt0128755',
               'follow the bitch': 'tt0119139',
               '101 dalmatians': 'tt011543',
               'steamboat willie': 'tt0019422',
               'henry: portrait of a serial killer': 'tt0099763',
               'attack of the killer tomatoes!': 'tt0080391',
               'little nemo: adventures in slumberland': 'tt0104740',
               'ten benny': 'tt0114008',
               'daddy long legs': 'tt0021775',
               'train ride to hollywood': 'tt0078412',
               'santitos': 'tt0126651',
               'it happened here': 'tt0055024',
               'last resort': 'tt0091387',
               'solar crisis': 'tt0100649',
               'kronos': 'tt0050610'} 

for index, row in ml_unmatched.iterrows():
    title = row['title']
    if(manual_matching_dict.get(title) != None): 
        row['tconst'] = manual_matching_dict.get(title)
        matched_df_full = matched_df_full.append(row)

# %%
matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))
# Out:
# all matches: (3762, 11)
# left to match: (175, 3)

# %%
imdb[imdb['title'] == 'mr. death']
# Out:
#            tconst      title  \
# 109869  tt0192335  mr. death
# 444844  tt7086072  mr. death
#
#                                             originalTitle  year
# 109869  mr. death: the rise and fall of fred a. leucht...  1999
# 444844                                          mr. death  2016

# %%
manual_matching_dict = {'misérables, les': 'tt0077936', 
               'shadows (cienie)': 'tt0245718',
               'castle freak': 'tt10701458',
               'dumb & dumber': 'tt0109686',
               'farinelli: il castrato': 'tt0109771',
               'interview with the vampire': 'tt1860252',
               'enfer l\'': 'tt13124824',
               'robert a. heinlein\'s the puppet masters': 'tt0111003',
               'harlem': 'tt0034950',
               'wedding gift, the': 'tt0847585',
               'ciao, professore! (io speriamo che me la cavo )': 'tt0107225',
               'dear diary (caro diario)': 'tt0109382',
               'superweib, das': 'tt0117788',
               'promise, the (versprechen, das)': 'tt0111613',
               'under the domin tree (etz hadomim tafus)': 'tt0109751',
               'two friends': '1986',
               'rendezvous in paris (rendez-vous de paris, les)': 'tt0176090',
               'crude oasis, the': 'tt0112746',
               'godzilla 2000 (gojira ni-sen mireniamu)': 'tt0120685',
               'broken hearts club, the': 'tt1194103',
               'crime and punishment in suburbia': 'tt0096056',
               'mad max 2 (a.k.a. the road warrior)': 'tt0079501',
               'toxic avenger, part ii, the': 'tt0090190',
               'spring fever usa (a.k.a. lauderdale)': 'tt0097717',
               'i am cuba (soy cuba/ya kuba)': 'tt0058604',
               'wisdom of crocodiles, the (a.k.a. immortality)': 'tt0120894',
               'mr. death: the rise and fall of fred a. leuchter, jr.': 'tt0192335'} 


for index, row in ml_unmatched.iterrows():
    title = row['title']
    if(manual_matching_dict.get(title) != None): 
        row['tconst'] = manual_matching_dict.get(title)
        matched_df_full = matched_df_full.append(row)   
        
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))
# Out:
# all matches: (3788, 11)
# left to match: (175, 3)

# %%
matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]

# %%
len(ml_unmatched)
# Out:
# 149

# %%
ml_unmatched.to_csv('unmatched.csv')

# %%
imdb[imdb['title'] == 'cool dry place']
# Out:
# Empty DataFrame
# Columns: [tconst, title, originalTitle, year]
# Index: []

# %%
manual_matching_dict = {'pink floyd - the wall': 'tt0084503', 
               'nosferatu a venezia': 'tt0091651',
               'good, the bad and the ugly, the': 'tt5083572',
               'two women (la ciociara)': 'tt0054749',
               'robert a. heinlein\'s the puppet masters': 'tt0111003',
                'the players club':'tt0119905',
                'big bang theory, the': 'tt1147717',
'jungle2jungle (a.k.a. jungle 2 jungle)' : 'tt0119432',
'boys, les' : 'tt0118764',
'prophecy ii, the' : 'tt0114194',
'machine, the':  'tt0933079',
'friday the 13th part 3: 3d' : 'tt0080761',
'karate kid, part ii, the' : 'tt0426060',
'empty mirror, the':  'tt0116192',
'citizen\'s band (a.k.a. handle with care)':  'tt0359987',
'hard 8 (a.k.a. sydney, a.k.a. hard eight)' : 'tt0119256' ,
'poison ivy: new seduction' : 'tt0105156' ,
'hard-boiled (lashou shentan)' : 'tt0104684',
'trial, the (le procés)':  'tt0057427',
'horror hotel (a.k.a. the city of the dead)' : 'tt0053719',
'two or three things i know about her' : 'tt0060304',
'vacation' : 'tt0015452',
'slaughterhouse 2':  'tt0093990'	,
'meatballs iii':  'tt0079540',
'children of the corn iii':  'tt0087050',
'seven beauties (pasqualino settebellezze)': 'tt0075040',
'lodger, the':  'tt0037024',
'vie est belle, la (life is rosey)' : 'tt0161066',
'communion (a.k.a. alice, sweet alice/holy terror)' : 'tt0188223',}

# %%
for index, row in ml_unmatched.iterrows():
    title = row['title']
    if(manual_matching_dict.get(title) != None): 
        row['tconst'] = manual_matching_dict.get(title)
        matched_df_full = matched_df_full.append(row)
        
matched_movie_ids = list(matched_df_full['movie_id'])
unmatched_movie_ids = set(unmatched_movie_ids) - set(matched_movie_ids)

ml_unmatched = ml_unmatched[ml_unmatched['movie_id'].isin(list(unmatched_movie_ids))]   
        
print("all matches: " + str(matched_df_full.shape))
print("left to match: " + str(ml_unmatched.shape))
# Out:
# all matches: (3840, 11)
# left to match: (123, 3)
